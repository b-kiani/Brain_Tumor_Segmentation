# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import os
import cv2
import tarfile
import warnings
import glob
import time
import numpy as np
import nibabel as nib
import pandas as pd
from sys import stdout
import matplotlib.pyplot as plt
import matplotlib.image as mpim
from scipy.ndimage.interpolation import affine_transform
from sklearn.model_selection import train_test_split
from skimage.util import montage 
from skimage.transform import rotate
from ipywidgets import interact, interactive, IntSlider, ToggleButtons

import tensorflow as tf
from tensorflow import keras
print('tf',tf.__version__)
print('keras',keras.__version__)
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Flatten, Conv3D, Conv3DTranspose, Dropout, ReLU, LeakyReLU, PReLU, ELU,
                                     Concatenate, Activation, ZeroPadding3D, MaxPooling3D, UpSampling3D)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.utils import plot_model, to_categorical
import tensorflow_addons as tfa
from tensorflow_addons.layers import InstanceNormalization
from tensorflow_addons.layers import GroupNormalization
from tensorflow_addons.layers import SpectralNormalization
warnings.filterwarnings("ignore")
plt.rcdefaults()

# Parameters
TRAIN_DATASET_PATH = './brain_images'
VALIDATION_DATASET_PATH = './val_brain_images'

SEGMENT_CLASSES = {
    0 : 'NOT tumor', # or Normal
    1 : 'NECROTIC/CORE', # or NON-ENHANCING tumor (CORE)
    2 : 'EDEMA',
    3 : 'ENHANCING' # original 4 -> converted into 3 later
}

VOLUME_SLICES = 128 
VOLUME_START_AT = 22
IMG_SIZE = 128
KERNEL_SIZE = 4
KERNEL_INIT = 'he_normal'
PAD='same'
DROP_RATE = 0.25
# Out:
# tf 2.8.0
# keras 2.8.0

# %% [markdown]
# ## download kaggle datasets in Google Drive

# %%
start = time.time()
tar = tarfile.open('archive/BraTS2021_Training_Data.tar')
tar.extractall('./brain_images')
tar.close()
end = time.time()
total_time = end - start
print(total_time)
# Out:
# 17.58183240890503

# %%
#!mkdir val_brain_images

# %%
tar = tarfile.open('archive/BraTS2021_00621.tar')
tar.extractall('./val_brain_images')
tar.close()

# %%
tar = tarfile.open('archive/BraTS2021_00495.tar')
tar.extractall('./val_brain_images')
tar.close()

# %% [markdown]
# ##Visualization

# %%
image_path = "./brain_images/BraTS2021_00284/BraTS2021_00284_t1.nii.gz"
t1_obj = nib.load(image_path)
print(type(t1_obj))
image_data = t1_obj.get_fdata()
print(type(image_data))
image_data.shape
# Out:
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'numpy.ndarray'>
# (240, 240, 155)

# %%
t1_hdr = t1_obj.header
print(t1_hdr)
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 0
# dim             : [  3 240 240 155   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [1. 1. 1. 1. 0. 0. 0. 0.]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 2
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b''
# aux_file        : b''
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.0
# quatern_c       : 0.0
# quatern_d       : 1.0
# qoffset_x       : 0.0
# qoffset_y       : 239.0
# qoffset_z       : 0.0
# srow_x          : [-1. -0. -0.  0.]
# srow_y          : [ -0.  -1.  -0. 239.]
# srow_z          : [0. 0. 1. 0.]
# intent_name     : b''
# magic           : b'n+1'

# %%
x_slice = image_data[59, :, :]
y_slice = image_data[:, 54, :]
z_slice = image_data[:, :, 64]
slices = [x_slice, y_slice, z_slice]

fig, axes = plt.subplots(1, len(slices))
for i, slice in enumerate(slices):
    axes[i].imshow(slice.T, cmap="gray", origin="lower")
    axes[i].axis('off')

# %%
def visualize_3d(layer):
    plt.figure(figsize=(10, 5))
    plt.imshow(image_data[:, :, layer], cmap='gray');#cmap='bone'
    plt.axis('off')
    return layer

interact(visualize_3d, layer=(0, image_data.shape[2] - 1));
# Out:
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…

# %%
layer = 50

def visualize_3d_labels(layer):
    mask = nib.load('./brain_images/BraTS2021_00284/BraTS2021_00284_seg.nii.gz').get_fdata()
    plt.imshow(mask[:,:,layer], cmap="bone")
    plt.axis('off')
    plt.tight_layout()

interact(visualize_3d_labels, layer=(0, image_data.shape[2] - 1));
# Out:
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…

# %%
layer = 50

def visualize_3d_labels(layer):
    mask = nib.load('./brain_images/BraTS2021_00284/BraTS2021_00284_seg.nii.gz').get_fdata()
    color_segmentation = np.zeros((240,240,3))
    gray_segmentation = mask[:,:,layer]
    color_segmentation[gray_segmentation == 1] = [255,0,0] # Red (necrotic tumor core)
    color_segmentation[gray_segmentation == 2] = [0,255,0] # Green (peritumoral edematous/invaded tissue)
    color_segmentation[gray_segmentation == 4] = [0,0,255] # Blue (enhancing tumor)
    plt.imshow(color_segmentation, cmap="gray") #cmap="bone"
    plt.axis('off')
    plt.tight_layout()

interact(visualize_3d_labels, layer=(0, image_data.shape[2] - 1));
# Out:
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (20,20))
ax1.imshow(rotate(montage(image_data[:,:,:]), 90, resize=True), cmap ='bone') #cmap ='gray'

# %%
mask = nib.load('./brain_images/BraTS2021_00284/BraTS2021_00284_seg.nii.gz').get_fdata()
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(mask[60:-60,:,:]), 90, resize=True), cmap ='bone')

# %%
# %cd /content/brain_images

img_ids = ["00376", "00789", "00441", "00703", "00807", "00523", "00241", "00778"]
SCAN_NUM = 83

for img_id in img_ids:
    plt.figure(figsize=(18, 5))

    for i, nii in enumerate([f'./brain_images/BraTS2021_{img_id}/BraTS2021_{img_id}_{s_type}.nii.gz' for s_type in ["flair", "t1", "t1ce", "t2", "seg"]]):
        plt.subplot(1,5,i+1)
        image = nib.load(nii).get_fdata()
        plt.title(nii.rsplit("_", 1)[1].split(".", 1)[0], fontweight="bold")
        plt.axis(False)
        plt.imshow(image[:, :, SCAN_NUM], cmap="bone")
        
    plt.tight_layout()    
    plt.show()

# %cd /content
# Out:
# [Errno 2] No such file or directory: '/content/brain_images'
# /home/serg-group/Desktop/danishvar/kiani
# [Errno 2] No such file or directory: '/content'
# /home/serg-group/Desktop/danishvar/kiani

# %% [markdown]
# ##Data Split by using Holdout Method

# %%
def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
    return x

train_and_val_directories = [f.path for f in os.scandir(TRAIN_DATASET_PATH) if f.is_dir()]
train_and_test_ids = pathListIntoIds(train_and_val_directories); 

train_ids, val_ids = train_test_split(train_and_test_ids,test_size=0.2) #test_size=0.25

# %% [markdown]
# ##Data Generator

# %%
class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE), batch_size = 1, n_channels = 4, shuffle=True):
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):

        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        Batch_ids = [self.list_IDs[k] for k in indexes]

        X, y = self.__data_generation(Batch_ids)
        
        return X, y

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels)) # X : (n_samples, *dim, n_channels)
        y = np.zeros((self.batch_size*VOLUME_SLICES, 128, 128))

        
        # data
        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATASET_PATH, i)

            data_path = os.path.join(case_path, f'{i}_flair.nii.gz');
            flair = nib.load(data_path).get_fdata()    

            data_path = os.path.join(case_path, f'{i}_t1ce.nii.gz');
            ce = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_t1.nii.gz');
            t1 = nib.load(data_path).get_fdata()    

            data_path = os.path.join(case_path, f'{i}_t2.nii.gz');
            t2 = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_seg.nii.gz');
            seg = nib.load(data_path).get_fdata()
        
            for j in range(VOLUME_SLICES):
             X[j+(VOLUME_SLICES*c),:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

             X[j+(VOLUME_SLICES*c),:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

             X[j+(VOLUME_SLICES*c),:,:,2] = cv2.resize(t1[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

             X[j+(VOLUME_SLICES*c),:,:,3] = cv2.resize(t2[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))             
             
             y[j +VOLUME_SLICES*c,:,:] = cv2.resize(seg[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

        X = X.reshape(1,128,128,128,4)
        y = y.reshape(1,128,128,128)

        # masks
        y[y==4] = 3;
        y = tf.one_hot(y, 4);

        return X/np.max(X), y

# %%
training_generator = DataGenerator(train_ids)
print(training_generator[0][0].shape)
valid_generator = DataGenerator(val_ids)
# Out:
# (1, 128, 128, 128, 4)
# 2022-05-24 09:28:38.244466: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-24 09:28:40.300514: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46712 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:3b:00.0, compute capability: 8.6
# 2022-05-24 09:28:40.301879: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46712 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:5e:00.0, compute capability: 8.6
# 2022-05-24 09:28:40.302335: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46712 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:86:00.0, compute capability: 8.6
# 2022-05-24 09:28:40.302819: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 46361 MB memory:  -> device: 3, name: NVIDIA RTX A6000, pci bus id: 0000:af:00.0, compute capability: 8.6

# %% [markdown]
# ##3D GAN Model

# %%
# Optimizers
generator_optimizer = Adam(2e-4, beta_1=0.5)
discriminator_optimizer = Adam(2e-4, beta_1=0.5)

# %% [markdown]
# ###Generator

# %%
def Gen():
################## Encoder ##################
  inputs = Input((128,128,128,4), name='input_image')
# Block 1
  x = Conv3D(64, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(inputs)
  x = ELU()(x)
  x = MaxPooling3D(pool_size=2, strides=2, name='MP1')(x)
  D1 = Dropout(DROP_RATE)(x)
# Block 2
  x = Conv3D(128, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(D1)
  x = GroupNormalization(groups=4, axis=4)(x)
  x = ELU()(x)
  x = MaxPooling3D(pool_size=2, strides=2, name='MP2')(x)
  D2 = Dropout(DROP_RATE)(x)
# Block 3
  x = Conv3D(192, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(D2)
  x = GroupNormalization(groups=4, axis=4)(x)
  x = ELU()(x)
  x = MaxPooling3D(pool_size=2, strides=2, name='MP3')(x)
  D3 = Dropout(DROP_RATE)(x)

# bottlenek
  # base
  x = Conv3D(256, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(D3)
  x = GroupNormalization(groups=4, axis=4)(x)
  x = ELU()(x)
  x = MaxPooling3D(pool_size=2, strides=2, name='MP4')(x)

  #1
  y = Conv3D(256, kernel_size=KERNEL_SIZE, strides=1, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = GroupNormalization(groups=4, axis=4)(y)
  x = ELU()(x)
  x = Concatenate()([x, y])

  #2
  y = Conv3D(256, kernel_size=KERNEL_SIZE, strides=1, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = GroupNormalization(groups=4, axis=4)(y)
  x = ELU()(x)
  x = Concatenate()([x, y])

  #3
  y = Conv3D(256, kernel_size=KERNEL_SIZE, strides=1, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = GroupNormalization(groups=4, axis=4)(y)
  x = ELU()(x)
  x = Concatenate()([x, y])

  #4
  y = Conv3D(256, kernel_size=KERNEL_SIZE, strides=1, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = GroupNormalization(groups=4, axis=4)(y)
  x = ELU()(x)
  x = Concatenate()([x, y])


################## Decoder ##################
  x = Conv3DTranspose(64, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = GroupNormalization(groups=4, axis=4)(x)
  x = ELU()(x)
  x = UpSampling3D(size=2)(x)
  x = Concatenate()([x, D3])
  x = Dropout(DROP_RATE)(x)

  x = Conv3DTranspose(64, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = GroupNormalization(groups=4, axis=4)(x)
  x = ELU()(x)
  x = UpSampling3D(size=2)(x)
  x = Concatenate()([x, D2])
  x = Dropout(DROP_RATE)(x)

  x = Conv3DTranspose(64, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = GroupNormalization(groups=4, axis=4)(x)
  x = ELU()(x)
  x = UpSampling3D(size=2)(x)
  x = Concatenate()([x, D1])
  x = Dropout(DROP_RATE)(x)


################## Output ##################
  out = Conv3DTranspose(4, kernel_size=KERNEL_SIZE, strides=2, kernel_initializer=KERNEL_INIT, padding=PAD, name='Gen_Output')(x)
  out = Activation('softmax')(out)
  return Model(inputs=inputs, outputs=out, name='Generator')

# %%
gen = Gen()
gen.summary(positions=[.33, .6, .7, 1.])
# Out:
# Model: "Generator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape              Param #   Connected to
# ==================================================================================================
#  input_image (InputLayer)       [(None, 128, 128, 128, 4  0         []
#                                 )]
#
#  conv3d (Conv3D)                (None, 128, 128, 128, 64  16448     ['input_image[0][0]']
#                                 )
#
#  elu (ELU)                      (None, 128, 128, 128, 64  0         ['conv3d[0][0]']
#                                 )
#
#  MP1 (MaxPooling3D)             (None, 64, 64, 64, 64)    0         ['elu[0][0]']
#
#  dropout (Dropout)              (None, 64, 64, 64, 64)    0         ['MP1[0][0]']
#
#  conv3d_1 (Conv3D)              (None, 64, 64, 64, 128)   524416    ['dropout[0][0]']
#
#  group_normalization (GroupNorm  (None, 64, 64, 64, 128)  256       ['conv3d_1[0][0]']
#  alization)
#
#  elu_1 (ELU)                    (None, 64, 64, 64, 128)   0         ['group_normalization[0][0]']
#
#  MP2 (MaxPooling3D)             (None, 32, 32, 32, 128)   0         ['elu_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 32, 32, 32, 128)   0         ['MP2[0][0]']
#
#  conv3d_2 (Conv3D)              (None, 32, 32, 32, 192)   1573056   ['dropout_1[0][0]']
#
#  group_normalization_1 (GroupNo  (None, 32, 32, 32, 192)  384       ['conv3d_2[0][0]']
#  rmalization)
#
#  elu_2 (ELU)                    (None, 32, 32, 32, 192)   0         ['group_normalization_1[0][0]'
#                                                                     ]
#
#  MP3 (MaxPooling3D)             (None, 16, 16, 16, 192)   0         ['elu_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 16, 16, 16, 192)   0         ['MP3[0][0]']
#
#  conv3d_3 (Conv3D)              (None, 16, 16, 16, 256)   3145984   ['dropout_2[0][0]']
#
#  group_normalization_2 (GroupNo  (None, 16, 16, 16, 256)  512       ['conv3d_3[0][0]']
#  rmalization)
#
#  elu_3 (ELU)                    (None, 16, 16, 16, 256)   0         ['group_normalization_2[0][0]'
#                                                                     ]
#
#  MP4 (MaxPooling3D)             (None, 8, 8, 8, 256)      0         ['elu_3[0][0]']
#
#  conv3d_4 (Conv3D)              (None, 8, 8, 8, 256)      4194560   ['MP4[0][0]']
#
#  group_normalization_3 (GroupNo  (None, 8, 8, 8, 256)     512       ['conv3d_4[0][0]']
#  rmalization)
#
#  elu_4 (ELU)                    (None, 8, 8, 8, 256)      0         ['group_normalization_3[0][0]'
#                                                                     ]
#
#  concatenate (Concatenate)      (None, 8, 8, 8, 512)      0         ['elu_4[0][0]',
#                                                                      'conv3d_4[0][0]']
#
#  conv3d_5 (Conv3D)              (None, 8, 8, 8, 256)      8388864   ['concatenate[0][0]']
#
#  group_normalization_4 (GroupNo  (None, 8, 8, 8, 256)     512       ['conv3d_5[0][0]']
#  rmalization)
#
#  elu_5 (ELU)                    (None, 8, 8, 8, 256)      0         ['group_normalization_4[0][0]'
#                                                                     ]
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 8, 512)      0         ['elu_5[0][0]',
#                                                                      'conv3d_5[0][0]']
#
#  conv3d_6 (Conv3D)              (None, 8, 8, 8, 256)      8388864   ['concatenate_1[0][0]']
#
#  group_normalization_5 (GroupNo  (None, 8, 8, 8, 256)     512       ['conv3d_6[0][0]']
#  rmalization)
#
#  elu_6 (ELU)                    (None, 8, 8, 8, 256)      0         ['group_normalization_5[0][0]'
#                                                                     ]
#
#  concatenate_2 (Concatenate)    (None, 8, 8, 8, 512)      0         ['elu_6[0][0]',
#                                                                      'conv3d_6[0][0]']
#
#  conv3d_7 (Conv3D)              (None, 8, 8, 8, 256)      8388864   ['concatenate_2[0][0]']
#
#  group_normalization_6 (GroupNo  (None, 8, 8, 8, 256)     512       ['conv3d_7[0][0]']
#  rmalization)
#
#  elu_7 (ELU)                    (None, 8, 8, 8, 256)      0         ['group_normalization_6[0][0]'
#                                                                     ]
#
#  concatenate_3 (Concatenate)    (None, 8, 8, 8, 512)      0         ['elu_7[0][0]',
#                                                                      'conv3d_7[0][0]']
#
#  conv3d_transpose (Conv3DTransp  (None, 8, 8, 8, 64)      2097216   ['concatenate_3[0][0]']
#  ose)
#
#  group_normalization_7 (GroupNo  (None, 8, 8, 8, 64)      128       ['conv3d_transpose[0][0]']
#  rmalization)
#
#  elu_8 (ELU)                    (None, 8, 8, 8, 64)       0         ['group_normalization_7[0][0]'
#                                                                     ]
#
#  up_sampling3d (UpSampling3D)   (None, 16, 16, 16, 64)    0         ['elu_8[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 16, 16, 16, 256)   0         ['up_sampling3d[0][0]',
#                                                                      'dropout_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 16, 16, 16, 256)   0         ['concatenate_4[0][0]']
#
#  conv3d_transpose_1 (Conv3DTran  (None, 16, 16, 16, 64)   1048640   ['dropout_3[0][0]']
#  spose)
#
#  group_normalization_8 (GroupNo  (None, 16, 16, 16, 64)   128       ['conv3d_transpose_1[0][0]']
#  rmalization)
#
#  elu_9 (ELU)                    (None, 16, 16, 16, 64)    0         ['group_normalization_8[0][0]'
#                                                                     ]
#
#  up_sampling3d_1 (UpSampling3D)  (None, 32, 32, 32, 64)   0         ['elu_9[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 32, 192)   0         ['up_sampling3d_1[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dropout_4 (Dropout)            (None, 32, 32, 32, 192)   0         ['concatenate_5[0][0]']
#
#  conv3d_transpose_2 (Conv3DTran  (None, 32, 32, 32, 64)   786496    ['dropout_4[0][0]']
#  spose)
#
#  group_normalization_9 (GroupNo  (None, 32, 32, 32, 64)   128       ['conv3d_transpose_2[0][0]']
#  rmalization)
#
#  elu_10 (ELU)                   (None, 32, 32, 32, 64)    0         ['group_normalization_9[0][0]'
#                                                                     ]
#
#  up_sampling3d_2 (UpSampling3D)  (None, 64, 64, 64, 64)   0         ['elu_10[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 64, 128)   0         ['up_sampling3d_2[0][0]',
#                                                                      'dropout[0][0]']
#
#  dropout_5 (Dropout)            (None, 64, 64, 64, 128)   0         ['concatenate_6[0][0]']
#
#  Gen_Output (Conv3DTranspose)   (None, 128, 128, 128, 4)  32772     ['dropout_5[0][0]']
#
#  activation (Activation)        (None, 128, 128, 128, 4)  0         ['Gen_Output[0][0]']
#
# ==================================================================================================
# Total params: 38,589,764
# Trainable params: 38,589,764
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(gen, to_file='gen_model.png', show_shapes=True, dpi=100)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %% [markdown]
# ###Discriminator

# %%
def Disc():
  inputs = Input((128,128,128,4), name='input_image')
  targets = Input((128,128,128,4), name='target_image')
  x = Concatenate()([inputs, targets])

# Block 1
  x = Conv3D(64, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding='same', name='C1')(x)
  x = ELU()(x)
  x = MaxPooling3D(pool_size=2, strides=2, name='MP1')(x)
  D1 = Dropout(DROP_RATE, name='D1')(x)

# Block 2
  x = SpectralNormalization(Conv3D(128, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding='same', name='C2'))(D1)
  x = ELU()(x)
  x = MaxPooling3D(pool_size=2, strides=2, name='MP2')(x)
  D2 = Dropout(DROP_RATE, name='D2')(x)

# Block 3
  x = SpectralNormalization(Conv3D(256, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding='same', name='C3'))(D2)
  x = ELU()(x)
  x = MaxPooling3D(pool_size=2, strides=2, name='MP3')(x)
  D3 = Dropout(DROP_RATE, name='D3')(x)
  x = ZeroPadding3D()(D3)

# Block 4
  x = SpectralNormalization(Conv3D(512, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding='same', name='C4'))(x)
  x = ELU()(x)
  x = MaxPooling3D(pool_size=2, strides=2, name='MP4')(x)   
  x = ZeroPadding3D()(x)

  out = Conv3D(1, kernel_size=KERNEL_SIZE, strides=1, padding='valid', kernel_initializer=KERNEL_INIT, name='disc_output')(x) 

  return Model(inputs=[targets, inputs], outputs=out, name='Discriminator')

# %%
disc = Disc()
disc.summary(positions=[.33, .6, .7, 1.])
# Out:
# Model: "Discriminator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape              Param #   Connected to
# ==================================================================================================
#  input_image (InputLayer)       [(None, 128, 128, 128, 4  0         []
#                                 )]
#
#  target_image (InputLayer)      [(None, 128, 128, 128, 4  0         []
#                                 )]
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 128, 8)  0         ['input_image[0][0]',
#                                                                      'target_image[0][0]']
#
#  C1 (Conv3D)                    (None, 128, 128, 128, 64  32832     ['concatenate_7[0][0]']
#                                 )
#
#  elu_11 (ELU)                   (None, 128, 128, 128, 64  0         ['C1[0][0]']
#                                 )
#
#  MP1 (MaxPooling3D)             (None, 64, 64, 64, 64)    0         ['elu_11[0][0]']
#
#  D1 (Dropout)                   (None, 64, 64, 64, 64)    0         ['MP1[0][0]']
#
#  spectral_normalization (Spectr  (None, 64, 64, 64, 128)  524544    ['D1[0][0]']
#  alNormalization)
#
#  elu_12 (ELU)                   (None, 64, 64, 64, 128)   0         ['spectral_normalization[0][0]
#                                                                     ']
#
#  MP2 (MaxPooling3D)             (None, 32, 32, 32, 128)   0         ['elu_12[0][0]']
#
#  D2 (Dropout)                   (None, 32, 32, 32, 128)   0         ['MP2[0][0]']
#
#  spectral_normalization_1 (Spec  (None, 32, 32, 32, 256)  2097664   ['D2[0][0]']
#  tralNormalization)
#
#  elu_13 (ELU)                   (None, 32, 32, 32, 256)   0         ['spectral_normalization_1[0][
#                                                                     0]']
#
#  MP3 (MaxPooling3D)             (None, 16, 16, 16, 256)   0         ['elu_13[0][0]']
#
#  D3 (Dropout)                   (None, 16, 16, 16, 256)   0         ['MP3[0][0]']
#
#  zero_padding3d (ZeroPadding3D)  (None, 18, 18, 18, 256)  0         ['D3[0][0]']
#
#  spectral_normalization_2 (Spec  (None, 18, 18, 18, 512)  8389632   ['zero_padding3d[0][0]']
#  tralNormalization)
#
#  elu_14 (ELU)                   (None, 18, 18, 18, 512)   0         ['spectral_normalization_2[0][
#                                                                     0]']
#
#  MP4 (MaxPooling3D)             (None, 9, 9, 9, 512)      0         ['elu_14[0][0]']
#
#  zero_padding3d_1 (ZeroPadding3  (None, 11, 11, 11, 512)  0         ['MP4[0][0]']
#  D)
#
#  disc_output (Conv3D)           (None, 8, 8, 8, 1)        32769     ['zero_padding3d_1[0][0]']
#
# ==================================================================================================
# Total params: 11,077,441
# Trainable params: 11,076,545
# Non-trainable params: 896
# __________________________________________________________________________________________________

# %%
plot_model(disc, to_file='disc_model.png', show_shapes=True, dpi=100)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %% [markdown]
# ##Losses
# ref:
# https://arxiv.org/pdf/1606.04797v1.pdf
#
# https://arxiv.org/abs/2112.13054

# %%
class_weights = np.array([0.25659472, 45.465614, 16.543337, 49.11155], dtype='float32')

def diceLoss(y_true, y_pred, class_weights):
    '''Dice = (2*|X & Y|)/ (|X|+ |Y|) = 2*sum(|A*B|)/(sum(A^2)+sum(B^2))'''
    y_true = tf.convert_to_tensor(y_true, 'float32')
    y_pred = tf.convert_to_tensor(y_pred, y_true.dtype)

    num = tf.math.reduce_sum(tf.math.multiply(class_weights, tf.math.reduce_sum(tf.math.multiply(y_true, y_pred), axis=[0,1,2,3])))
    den = tf.math.reduce_sum(tf.math.multiply(class_weights, tf.math.reduce_sum(tf.math.add(y_true, y_pred), axis=[0,1,2,3])))+1e-5

    return 1-2*num/den

def discriminator_loss(disc_real_output, disc_fake_output):
    real_loss = tf.math.reduce_mean(tf.math.pow(tf.ones_like(disc_real_output) - disc_real_output, 2))
    fake_loss = tf.math.reduce_mean(tf.math.pow(tf.zeros_like(disc_fake_output) - disc_fake_output, 2))

    disc_loss = 0.5*(real_loss + fake_loss)

    return disc_loss


def generator_loss(target, gen_output, disc_fake_output, class_weights, alpha):
    
    # dice loss
    dice_loss = diceLoss(target, gen_output, class_weights)
    
    # disc loss
    disc_loss = tf.math.reduce_mean(tf.math.pow(tf.ones_like(disc_fake_output) - disc_fake_output, 2))
       
    # total loss
    gen_loss = alpha*dice_loss + disc_loss

    return gen_loss, dice_loss, disc_loss

# %% [markdown]
# ##Training Function

# %%
@tf.function
def train_step(image, target, alpha):
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:

        gen_output = gen(image, training=True)

        disc_real_output = disc([image, target], training=True)
        disc_fake_output = disc([image, gen_output], training=True)
        disc_loss = discriminator_loss(disc_real_output, disc_fake_output)
        
        gen_loss, dice_loss, disc_loss_gen = generator_loss(target, gen_output, disc_fake_output, class_weights, alpha)
    # Calculate the gradients
    generator_gradients = gen_tape.gradient(gen_loss, gen.trainable_variables)
    discriminator_gradients = disc_tape.gradient(disc_loss, disc.trainable_variables)
    # Apply the gradients
    generator_optimizer.apply_gradients(zip(generator_gradients, gen.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(discriminator_gradients, disc.trainable_variables))
        
    return gen_loss, dice_loss, disc_loss_gen
        
@tf.function
def test_step(image, target, alpha):
    gen_output = gen(image, training=False)

    disc_real_output = disc([image, target], training=False)
    disc_fake_output = disc([image, gen_output], training=False)
    disc_loss = discriminator_loss(disc_real_output, disc_fake_output)

    gen_loss, dice_loss, disc_loss_gen = generator_loss(target, gen_output, disc_fake_output, class_weights, alpha)
        
    return gen_loss, dice_loss, disc_loss_gen

def fit(train_gen, valid_gen, alpha, epochs):
    # path = './RESULTS' #saving in content
    path = 'RESULTS' ##saving in drive
    if os.path.exists(path)==False:
        os.mkdir(path)
        
    Nt = len(train_gen)
    history = {'train': [], 'valid': []}
    prev_loss = np.inf
    
    epoch_v2v_loss = tf.keras.metrics.Mean()
    epoch_dice_loss = tf.keras.metrics.Mean()
    epoch_disc_loss = tf.keras.metrics.Mean()
    epoch_v2v_loss_val = tf.keras.metrics.Mean()
    epoch_dice_loss_val = tf.keras.metrics.Mean()
    epoch_disc_loss_val = tf.keras.metrics.Mean()
    
    for e in range(epochs):
        print('Epoch {}/{}'.format(e+1,epochs))
        b = 0
        for Xb, yb in train_gen:
            b += 1
            losses = train_step(Xb, yb, alpha)
            epoch_v2v_loss.update_state(losses[0])
            epoch_dice_loss.update_state(losses[1])
            epoch_disc_loss.update_state(losses[2])
            # epoch_m_iou.update_state()
            
            stdout.write('\rBatch: {}/{} - loss: {:.4f} - dice_loss: {:.4f} - disc_loss: {:.4f}'
                         .format(b, Nt, epoch_v2v_loss.result(), epoch_dice_loss.result(), epoch_disc_loss.result()))
            stdout.flush()
        history['train'].append([epoch_v2v_loss.result(), epoch_dice_loss.result(), epoch_disc_loss.result()])
        
        for Xb, yb in valid_gen:
            losses_val = test_step(Xb, yb, alpha)
            epoch_v2v_loss_val.update_state(losses_val[0])
            epoch_dice_loss_val.update_state(losses_val[1])
            epoch_disc_loss_val.update_state(losses_val[2])
            
        stdout.write('\n               loss_val: {:.4f} - dice_loss_val: {:.4f} - disc_loss_val: {:.4f}'
                     .format(epoch_v2v_loss_val.result(), epoch_dice_loss_val.result(), epoch_disc_loss_val.result()))
        stdout.flush()
        history['valid'].append([epoch_v2v_loss_val.result(), epoch_dice_loss_val.result(), epoch_disc_loss_val.result()])
        
        # save pred image at epoch e 
        y_pred = gen.predict(Xb)
        y_true = np.argmax(yb, axis=-1)
        y_pred = np.argmax(y_pred, axis=-1)

        canvas = np.zeros((128, 128*3))
        idx = np.random.randint(len(Xb))
        
        x = Xb[idx,:,:,64,2] 
        canvas[0:128, 0:128] = (x - np.min(x))/(np.max(x)-np.min(x)+1e-6)
        canvas[0:128, 128:2*128] = y_true[idx,:,:,64]/3
        canvas[0:128, 2*128:3*128] = y_pred[idx,:,:,64]/3
        
        fname = (path + '/pred@epoch_{:03d}.png').format(e+1)
        mpim.imsave(fname, canvas, cmap='gray')
        
        # save models
        print(' ')
        if epoch_v2v_loss_val.result() < prev_loss:    
            gen.save_weights(path + '/Generator.h5') 
            disc.save_weights(path + '/Discriminator.h5')
            print("Validation loss decresaed from {:.4f} to {:.4f}. Models' weights are now saved.".format(prev_loss, epoch_v2v_loss_val.result()))
            prev_loss = epoch_v2v_loss_val.result()
        else:
            print("Validation loss did not decrease from {:.4f}.".format(prev_loss))
        print(' ')
        
        # resets losses states
        epoch_v2v_loss.reset_states()
        epoch_dice_loss.reset_states()
        epoch_disc_loss.reset_states()
        epoch_v2v_loss_val.reset_states()
        epoch_dice_loss_val.reset_states()
        epoch_disc_loss_val.reset_states()
        
        del Xb, yb, canvas, y_pred, y_true, idx
        
    return history

# %%
# Load saved Model
gen.load_weights('RESULTS/Generator.h5')
print(' Gererator is loaded.')
disc.load_weights('RESULTS/Discriminator.h5')
print(' Discriminator is loaded.')
# Out:
#  Gererator is loaded.
#  Discriminator is loaded.

# %% [markdown]
# ##Training and Testing

# %%
start = time.time()
alpha = 5
n_epochs = 151
h = fit(training_generator, valid_generator, alpha, n_epochs)
end = time.time()
total_time = end - start
print(total_time)
# Out:
# Epoch 1/151
# 2022-05-24 09:28:49.737717: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2022-05-24 09:28:50.716328: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8200
# 2022-05-24 09:28:52.150342: W tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2022-05-24 09:28:52.151769: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.6
# 2022-05-24 09:28:52.151779: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at ptxas
# 2022-05-24 09:28:52.152047: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# Batch: 1000/1000 - loss: 4.3885 - dice_loss: 0.3553 - disc_loss: 2.611893
#                loss_val: 1.8327 - dice_loss_val: 0.3492 - disc_loss_val: 0.0866
# Validation loss decresaed from inf to 1.8327. Models' weights are now saved.
#
# Epoch 2/151
# Batch: 1000/1000 - loss: 2.1668 - dice_loss: 0.3551 - disc_loss: 0.3914
#                loss_val: 2.5548 - dice_loss_val: 0.3602 - disc_loss_val: 0.7538
# Validation loss did not decrease from 1.8327.
#
# Epoch 3/151
# Batch: 1000/1000 - loss: 382.5031 - dice_loss: 0.3890 - disc_loss: 380.5581
#                loss_val: 5.0695 - dice_loss_val: 0.4024 - disc_loss_val: 3.0575
# Validation loss did not decrease from 1.8327.
#
# Epoch 4/151
# Batch: 1000/1000 - loss: 2.3943 - dice_loss: 0.3965 - disc_loss: 0.4117
#                loss_val: 4.3872 - dice_loss_val: 0.4022 - disc_loss_val: 2.3762
# Validation loss did not decrease from 1.8327.
#
# Epoch 5/151
# Batch: 1000/1000 - loss: 2.2704 - dice_loss: 0.3790 - disc_loss: 0.3755
#                loss_val: 2.8955 - dice_loss_val: 0.3601 - disc_loss_val: 1.0951
# Validation loss did not decrease from 1.8327.
#
# Epoch 6/151
# Batch: 1000/1000 - loss: 2.0674 - dice_loss: 0.3484 - disc_loss: 0.3252
#                loss_val: 2.7416 - dice_loss_val: 0.3580 - disc_loss_val: 0.9514
# Validation loss did not decrease from 1.8327.
#
# Epoch 7/151
# Batch: 1000/1000 - loss: 85.2051 - dice_loss: 0.3554 - disc_loss: 83.42839
#                loss_val: 2.3867 - dice_loss_val: 0.3929 - disc_loss_val: 0.4219
# Validation loss did not decrease from 1.8327.
#
# Epoch 8/151
# Batch: 1000/1000 - loss: 2.3158 - dice_loss: 0.3935 - disc_loss: 0.3482
#                loss_val: 2.2079 - dice_loss_val: 0.3892 - disc_loss_val: 0.2618
# Validation loss did not decrease from 1.8327.
#
# Epoch 9/151
# Batch: 1000/1000 - loss: 2.2283 - dice_loss: 0.3871 - disc_loss: 0.2929
#                loss_val: 2.1463 - dice_loss_val: 0.3812 - disc_loss_val: 0.2402
# Validation loss did not decrease from 1.8327.
#
# Epoch 10/151
# Batch: 1000/1000 - loss: 2.1907 - dice_loss: 0.3760 - disc_loss: 0.3109
#                loss_val: 2.1115 - dice_loss_val: 0.3682 - disc_loss_val: 0.2707
# Validation loss did not decrease from 1.8327.
#
# Epoch 11/151
# Batch: 1000/1000 - loss: 2.1396 - dice_loss: 0.3627 - disc_loss: 0.3259
#                loss_val: 2.2169 - dice_loss_val: 0.3577 - disc_loss_val: 0.4285
# Validation loss did not decrease from 1.8327.
#
# Epoch 12/151
# Batch: 1000/1000 - loss: 2.1308 - dice_loss: 0.3530 - disc_loss: 0.3657
#                loss_val: 2.4111 - dice_loss_val: 0.3509 - disc_loss_val: 0.6569
# Validation loss did not decrease from 1.8327.
#
# Epoch 13/151
# Batch: 1000/1000 - loss: 2.1908 - dice_loss: 0.3507 - disc_loss: 0.4375
#                loss_val: 2.5239 - dice_loss_val: 0.3514 - disc_loss_val: 0.7671
# Validation loss did not decrease from 1.8327.
#
# Epoch 14/151
# Batch: 1000/1000 - loss: 209.0255 - dice_loss: 0.3886 - disc_loss: 207.08275
#                loss_val: 2.0252 - dice_loss_val: 0.3856 - disc_loss_val: 0.0971
# Validation loss did not decrease from 1.8327.
#
# Epoch 15/151
# Batch: 1000/1000 - loss: 2.2357 - dice_loss: 0.3834 - disc_loss: 0.3186
#                loss_val: 1.9650 - dice_loss_val: 0.3848 - disc_loss_val: 0.0410
# Validation loss did not decrease from 1.8327.
#
# Epoch 16/151
# Batch: 1000/1000 - loss: 2.2432 - dice_loss: 0.3812 - disc_loss: 0.3370
#                loss_val: 1.9799 - dice_loss_val: 0.3836 - disc_loss_val: 0.0617
# Validation loss did not decrease from 1.8327.
#
# Epoch 17/151
# Batch: 1000/1000 - loss: 2.2399 - dice_loss: 0.3788 - disc_loss: 0.3459
#                loss_val: 1.9423 - dice_loss_val: 0.3808 - disc_loss_val: 0.0385
# Validation loss did not decrease from 1.8327.
#
# Epoch 18/151
# Batch: 1000/1000 - loss: 2.2142 - dice_loss: 0.3735 - disc_loss: 0.3465
#                loss_val: 1.9372 - dice_loss_val: 0.3723 - disc_loss_val: 0.0757
# Validation loss did not decrease from 1.8327.
#
# Epoch 19/151
# Batch: 1000/1000 - loss: 2.1603 - dice_loss: 0.3613 - disc_loss: 0.3538
#                loss_val: 1.9602 - dice_loss_val: 0.3587 - disc_loss_val: 0.1667
# Validation loss did not decrease from 1.8327.
#
# Epoch 20/151
# Batch: 1000/1000 - loss: 2.1232 - dice_loss: 0.3493 - disc_loss: 0.3765
#                loss_val: 2.0179 - dice_loss_val: 0.3518 - disc_loss_val: 0.2588
# Validation loss did not decrease from 1.8327.
#
# Epoch 21/151
# Batch: 1000/1000 - loss: 2.1881 - dice_loss: 0.3444 - disc_loss: 0.4661
#                loss_val: 1.8926 - dice_loss_val: 0.3543 - disc_loss_val: 0.1214
# Validation loss did not decrease from 1.8327.
#
# Epoch 22/151
# Batch: 1000/1000 - loss: 2.2736 - dice_loss: 0.3418 - disc_loss: 0.5644
#                loss_val: 1.9146 - dice_loss_val: 0.3445 - disc_loss_val: 0.1922
# Validation loss did not decrease from 1.8327.
#
# Epoch 23/151
# Batch: 1000/1000 - loss: 1075.0309 - dice_loss: 0.7239 - disc_loss: 1071.4080
#                loss_val: 8.9660 - dice_loss_val: 0.9377 - disc_loss_val: 4.2774
# Validation loss did not decrease from 1.8327.
#
# Epoch 24/151
# Batch: 1000/1000 - loss: 5.7408 - dice_loss: 0.9382 - disc_loss: 1.0496
#                loss_val: 7.0061 - dice_loss_val: 0.9375 - disc_loss_val: 2.3188
# Validation loss did not decrease from 1.8327.
#
# Epoch 25/151
# Batch: 1000/1000 - loss: 5.7008 - dice_loss: 0.9380 - disc_loss: 1.0110
#                loss_val: 6.9298 - dice_loss_val: 0.9371 - disc_loss_val: 2.2442
# Validation loss did not decrease from 1.8327.
#
# Epoch 26/151
# Batch: 1000/1000 - loss: 5.7137 - dice_loss: 0.9376 - disc_loss: 1.0258
#                loss_val: 5.9649 - dice_loss_val: 0.9366 - disc_loss_val: 1.2819
# Validation loss did not decrease from 1.8327.
#
# Epoch 27/151
# Batch: 1000/1000 - loss: 5.7303 - dice_loss: 0.9370 - disc_loss: 1.0454
#                loss_val: 5.5298 - dice_loss_val: 0.9358 - disc_loss_val: 0.8508
# Validation loss did not decrease from 1.8327.
#
# Epoch 28/151
# Batch: 1000/1000 - loss: 5.7299 - dice_loss: 0.9360 - disc_loss: 1.0500
#                loss_val: 5.4906 - dice_loss_val: 0.9344 - disc_loss_val: 0.8185
# Validation loss did not decrease from 1.8327.
#
# Epoch 29/151
# Batch: 1000/1000 - loss: 5.7045 - dice_loss: 0.9341 - disc_loss: 1.0339
#                loss_val: 5.6103 - dice_loss_val: 0.9316 - disc_loss_val: 0.9522
# Validation loss did not decrease from 1.8327.
#
# Epoch 30/151
# Batch: 1000/1000 - loss: 5.6578 - dice_loss: 0.9295 - disc_loss: 1.0102
#                loss_val: 5.2952 - dice_loss_val: 0.9182 - disc_loss_val: 0.7041
# Validation loss did not decrease from 1.8327.
#
# Epoch 31/151
# Batch: 1000/1000 - loss: 4.0218 - dice_loss: 0.6695 - disc_loss: 0.6742
#                loss_val: 2.4328 - dice_loss_val: 0.4316 - disc_loss_val: 0.2749
# Validation loss did not decrease from 1.8327.
#
# Epoch 32/151
# Batch: 1000/1000 - loss: 2.3679 - dice_loss: 0.4125 - disc_loss: 0.3051
#                loss_val: 2.5075 - dice_loss_val: 0.4101 - disc_loss_val: 0.4570
# Validation loss did not decrease from 1.8327.
#
# Epoch 33/151
# Batch: 1000/1000 - loss: 2.3762 - dice_loss: 0.4022 - disc_loss: 0.3653
#                loss_val: 2.1481 - dice_loss_val: 0.4054 - disc_loss_val: 0.1214
# Validation loss did not decrease from 1.8327.
#
# Epoch 34/151
# Batch: 1000/1000 - loss: 2.5179 - dice_loss: 0.3997 - disc_loss: 0.5193
#                loss_val: 2.0868 - dice_loss_val: 0.4042 - disc_loss_val: 0.0660
# Validation loss did not decrease from 1.8327.
#
# Epoch 35/151
# Batch: 1000/1000 - loss: 1556.3660 - dice_loss: 0.4851 - disc_loss: 1553.9404
#                loss_val: 6.8482 - dice_loss_val: 0.9937 - disc_loss_val: 1.8799
# Validation loss did not decrease from 1.8327.
#
# Epoch 36/151
# Batch: 1000/1000 - loss: 9.7406 - dice_loss: 0.9938 - disc_loss: 4.7715
#                loss_val: 10.3432 - dice_loss_val: 0.9939 - disc_loss_val: 5.3736
# Validation loss did not decrease from 1.8327.
#
# Epoch 37/151
# Batch: 1000/1000 - loss: 12.9265 - dice_loss: 0.9939 - disc_loss: 7.9568
#                loss_val: 25.9794 - dice_loss_val: 0.9938 - disc_loss_val: 21.0102
# Validation loss did not decrease from 1.8327.
#
# Epoch 38/151
# Batch: 1000/1000 - loss: 20.0755 - dice_loss: 0.9937 - disc_loss: 15.1071
#                loss_val: 5.2237 - dice_loss_val: 0.9935 - disc_loss_val: 0.2561
# Validation loss did not decrease from 1.8327.
#
# Epoch 39/151
# Batch: 1000/1000 - loss: 6.0725 - dice_loss: 0.9932 - disc_loss: 1.1065
#                loss_val: 5.0760 - dice_loss_val: 0.9929 - disc_loss_val: 0.1116
# Validation loss did not decrease from 1.8327.
#
# Epoch 40/151
# Batch: 1000/1000 - loss: 6.8132 - dice_loss: 0.9928 - disc_loss: 1.8494
#                loss_val: 6.0493 - dice_loss_val: 0.9925 - disc_loss_val: 1.0868
# Validation loss did not decrease from 1.8327.
#
# Epoch 41/151
# Batch: 1000/1000 - loss: 7.2868 - dice_loss: 0.9917 - disc_loss: 2.3282
#                loss_val: 9.6287 - dice_loss_val: 0.9889 - disc_loss_val: 4.6840
# Validation loss did not decrease from 1.8327.
#
# Epoch 42/151
# Batch: 1000/1000 - loss: 6.9708 - dice_loss: 0.9882 - disc_loss: 2.0299
#                loss_val: 6.1282 - dice_loss_val: 0.9868 - disc_loss_val: 1.1942
# Validation loss did not decrease from 1.8327.
#
# Epoch 43/151
# Batch: 1000/1000 - loss: 6.7576 - dice_loss: 0.9771 - disc_loss: 1.8722
#                loss_val: 5.3248 - dice_loss_val: 0.9572 - disc_loss_val: 0.5386
# Validation loss did not decrease from 1.8327.
#
# Epoch 44/151
# Batch: 1000/1000 - loss: 6.1635 - dice_loss: 0.9013 - disc_loss: 1.6568
#                loss_val: 3.8198 - dice_loss_val: 0.6824 - disc_loss_val: 0.4079
# Validation loss did not decrease from 1.8327.
#
# Epoch 45/151
# Batch: 1000/1000 - loss: 3.0197 - dice_loss: 0.4264 - disc_loss: 0.8875
#                loss_val: 2.1742 - dice_loss_val: 0.4032 - disc_loss_val: 0.1579
# Validation loss did not decrease from 1.8327.
#
# Epoch 46/151
# Batch: 1000/1000 - loss: 2.7437 - dice_loss: 0.3990 - disc_loss: 0.7486
#                loss_val: 2.0810 - dice_loss_val: 0.4040 - disc_loss_val: 0.0608
# Validation loss did not decrease from 1.8327.
#
# Epoch 47/151
# Batch: 1000/1000 - loss: 2.7284 - dice_loss: 0.4065 - disc_loss: 0.6960
#                loss_val: 2.2232 - dice_loss_val: 0.4040 - disc_loss_val: 0.2031
# Validation loss did not decrease from 1.8327.
#
# Epoch 48/151
# Batch: 1000/1000 - loss: 199.3594 - dice_loss: 0.3989 - disc_loss: 197.3648
#                loss_val: 2.7349 - dice_loss_val: 0.4027 - disc_loss_val: 0.7215
# Validation loss did not decrease from 1.8327.
#
# Epoch 49/151
# Batch: 1000/1000 - loss: 2.3698 - dice_loss: 0.3968 - disc_loss: 0.3858
#                loss_val: 2.7101 - dice_loss_val: 0.4023 - disc_loss_val: 0.6984
# Validation loss did not decrease from 1.8327.
#
# Epoch 50/151
# Batch: 1000/1000 - loss: 2.4046 - dice_loss: 0.3965 - disc_loss: 0.4220
#                loss_val: 2.6636 - dice_loss_val: 0.4022 - disc_loss_val: 0.6527
# Validation loss did not decrease from 1.8327.
#
# Epoch 51/151
# Batch: 1000/1000 - loss: 2.4640 - dice_loss: 0.3964 - disc_loss: 0.4821
#                loss_val: 2.6541 - dice_loss_val: 0.4021 - disc_loss_val: 0.6435
# Validation loss did not decrease from 1.8327.
#
# Epoch 52/151
# Batch: 1000/1000 - loss: 2.5423 - dice_loss: 0.3963 - disc_loss: 0.5608
#                loss_val: 2.6453 - dice_loss_val: 0.4021 - disc_loss_val: 0.6350
# Validation loss did not decrease from 1.8327.
#
# Epoch 53/151
# Batch: 1000/1000 - loss: 2.5496 - dice_loss: 0.3963 - disc_loss: 0.5683
#                loss_val: 2.7265 - dice_loss_val: 0.4020 - disc_loss_val: 0.7163
# Validation loss did not decrease from 1.8327.
#
# Epoch 54/151
# Batch: 1000/1000 - loss: 2.5443 - dice_loss: 0.3962 - disc_loss: 0.5630
#                loss_val: 2.8302 - dice_loss_val: 0.4020 - disc_loss_val: 0.8201
# Validation loss did not decrease from 1.8327.
#
# Epoch 55/151
# Batch: 1000/1000 - loss: 2.5876 - dice_loss: 0.3962 - disc_loss: 0.6064
#                loss_val: 2.9092 - dice_loss_val: 0.4020 - disc_loss_val: 0.8992
# Validation loss did not decrease from 1.8327.
#
# Epoch 56/151
# Batch: 1000/1000 - loss: 2.6519 - dice_loss: 0.3964 - disc_loss: 0.6700
#                loss_val: 2.9910 - dice_loss_val: 0.4018 - disc_loss_val: 0.9821
# Validation loss did not decrease from 1.8327.
#
# Epoch 57/151
# Batch: 1000/1000 - loss: 173.5697 - dice_loss: 0.3960 - disc_loss: 171.5899
#                loss_val: 2.1592 - dice_loss_val: 0.4020 - disc_loss_val: 0.1491
# Validation loss did not decrease from 1.8327.
#
# Epoch 58/151
# Batch: 1000/1000 - loss: 2.3235 - dice_loss: 0.3957 - disc_loss: 0.3450
#                loss_val: 2.1355 - dice_loss_val: 0.4014 - disc_loss_val: 0.1286
# Validation loss did not decrease from 1.8327.
#
# Epoch 59/151
# Batch: 1000/1000 - loss: 2.3692 - dice_loss: 0.3964 - disc_loss: 0.3870
#                loss_val: 2.2228 - dice_loss_val: 0.4039 - disc_loss_val: 0.2033
# Validation loss did not decrease from 1.8327.
#
# Epoch 60/151
# Batch: 1000/1000 - loss: 2.2556 - dice_loss: 0.3899 - disc_loss: 0.3062
#                loss_val: 1.9934 - dice_loss_val: 0.3574 - disc_loss_val: 0.2062
# Validation loss did not decrease from 1.8327.
#
# Epoch 61/151
# Batch: 1000/1000 - loss: 1.9358 - dice_loss: 0.3299 - disc_loss: 0.2861
#                loss_val: 1.7880 - dice_loss_val: 0.3125 - disc_loss_val: 0.2253
# Validation loss decresaed from 1.8327 to 1.7880. Models' weights are now saved.
#
# Epoch 62/151
# Batch: 1000/1000 - loss: 1.8351 - dice_loss: 0.3067 - disc_loss: 0.3015
#                loss_val: 1.7107 - dice_loss_val: 0.2941 - disc_loss_val: 0.2403
# Validation loss decresaed from 1.7880 to 1.7107. Models' weights are now saved.
#
# Epoch 63/151
# Batch: 1000/1000 - loss: 1.7623 - dice_loss: 0.2910 - disc_loss: 0.3073
#                loss_val: 1.8155 - dice_loss_val: 0.2838 - disc_loss_val: 0.3967
# Validation loss did not decrease from 1.7107.
#
# Epoch 64/151
# Batch: 1000/1000 - loss: 1933.3348 - dice_loss: 0.3408 - disc_loss: 1931.6334
#                loss_val: 3.6689 - dice_loss_val: 0.4005 - disc_loss_val: 1.6663
# Validation loss did not decrease from 1.7107.
#
# Epoch 65/151
# Batch: 1000/1000 - loss: 3.1754 - dice_loss: 0.3957 - disc_loss: 1.1970
#                loss_val: 2.8612 - dice_loss_val: 0.4005 - disc_loss_val: 0.8589
# Validation loss did not decrease from 1.7107.
#
# Epoch 66/151
# Batch: 1000/1000 - loss: 2.4730 - dice_loss: 0.3956 - disc_loss: 0.4951
#                loss_val: 2.8608 - dice_loss_val: 0.4004 - disc_loss_val: 0.8590
# Validation loss did not decrease from 1.7107.
#
# Epoch 67/151
# Batch: 1000/1000 - loss: 2.4331 - dice_loss: 0.3955 - disc_loss: 0.4558
#                loss_val: 2.7662 - dice_loss_val: 0.4003 - disc_loss_val: 0.7646
# Validation loss did not decrease from 1.7107.
#
# Epoch 68/151
# Batch: 1000/1000 - loss: 2.4169 - dice_loss: 0.3951 - disc_loss: 0.4413
#                loss_val: 2.7146 - dice_loss_val: 0.4003 - disc_loss_val: 0.7130
# Validation loss did not decrease from 1.7107.
#
# Epoch 69/151
# Batch: 1000/1000 - loss: 2.3833 - dice_loss: 0.3948 - disc_loss: 0.4095
#                loss_val: 2.7403 - dice_loss_val: 0.4003 - disc_loss_val: 0.7390
# Validation loss did not decrease from 1.7107.
#
# Epoch 70/151
# Batch: 1000/1000 - loss: 2.4682 - dice_loss: 0.3942 - disc_loss: 0.4973
#                loss_val: 2.2595 - dice_loss_val: 0.3995 - disc_loss_val: 0.2619
# Validation loss did not decrease from 1.7107.
#
# Epoch 71/151
# Batch: 1000/1000 - loss: 5.1055 - dice_loss: 0.3936 - disc_loss: 3.1374
#                loss_val: 2.2009 - dice_loss_val: 0.3980 - disc_loss_val: 0.2109
# Validation loss did not decrease from 1.7107.
#
# Epoch 72/151
# Batch: 1000/1000 - loss: 2.2166 - dice_loss: 0.3906 - disc_loss: 0.2636
#                loss_val: 2.1710 - dice_loss_val: 0.3965 - disc_loss_val: 0.1887
# Validation loss did not decrease from 1.7107.
#
# Epoch 73/151
# Batch: 1000/1000 - loss: 2.2214 - dice_loss: 0.3899 - disc_loss: 0.2717
#                loss_val: 2.2583 - dice_loss_val: 0.3956 - disc_loss_val: 0.2801
# Validation loss did not decrease from 1.7107.
#
# Epoch 74/151
# Batch: 1000/1000 - loss: 2.2325 - dice_loss: 0.3888 - disc_loss: 0.2885
#                loss_val: 2.4552 - dice_loss_val: 0.3940 - disc_loss_val: 0.4852
# Validation loss did not decrease from 1.7107.
#
# Epoch 75/151
# Batch: 1000/1000 - loss: 2.2986 - dice_loss: 0.3876 - disc_loss: 0.3606
#                loss_val: 2.9047 - dice_loss_val: 0.3916 - disc_loss_val: 0.9464
# Validation loss did not decrease from 1.7107.
#
# Epoch 76/151
# Batch: 1000/1000 - loss: 515.8384 - dice_loss: 0.3927 - disc_loss: 513.87504
#                loss_val: 2.6391 - dice_loss_val: 0.4022 - disc_loss_val: 0.6282
# Validation loss did not decrease from 1.7107.
#
# Epoch 77/151
# Batch: 1000/1000 - loss: 2.5389 - dice_loss: 0.3964 - disc_loss: 0.5569
#                loss_val: 2.1229 - dice_loss_val: 0.4022 - disc_loss_val: 0.1121
# Validation loss did not decrease from 1.7107.
#
# Epoch 78/151
# Batch: 1000/1000 - loss: 2.8823 - dice_loss: 0.3964 - disc_loss: 0.9005
#                loss_val: 2.0475 - dice_loss_val: 0.4021 - disc_loss_val: 0.0369
# Validation loss did not decrease from 1.7107.
#
# Epoch 79/151
# Batch: 1000/1000 - loss: 3.1884 - dice_loss: 0.3963 - disc_loss: 1.2069
#                loss_val: 2.0660 - dice_loss_val: 0.4021 - disc_loss_val: 0.0555
# Validation loss did not decrease from 1.7107.
#
# Epoch 80/151
# Batch: 1000/1000 - loss: 3.1725 - dice_loss: 0.3963 - disc_loss: 1.1912
#                loss_val: 2.1138 - dice_loss_val: 0.4021 - disc_loss_val: 0.1035
# Validation loss did not decrease from 1.7107.
#
# Epoch 81/151
# Batch: 1000/1000 - loss: 3.3927 - dice_loss: 0.3962 - disc_loss: 1.4115
#                loss_val: 2.9329 - dice_loss_val: 0.4020 - disc_loss_val: 0.9229
# Validation loss did not decrease from 1.7107.
#
# Epoch 82/151
# Batch: 1000/1000 - loss: 201.1861 - dice_loss: 0.3962 - disc_loss: 199.2052
#                loss_val: 2.1854 - dice_loss_val: 0.4020 - disc_loss_val: 0.1754
# Validation loss did not decrease from 1.7107.
#
# Epoch 83/151
# Batch: 1000/1000 - loss: 2.3983 - dice_loss: 0.3962 - disc_loss: 0.4173
#                loss_val: 2.2612 - dice_loss_val: 0.4022 - disc_loss_val: 0.2503
# Validation loss did not decrease from 1.7107.
#
# Epoch 84/151
# Batch: 1000/1000 - loss: 2.3941 - dice_loss: 0.3993 - disc_loss: 0.3976
#                loss_val: 2.2238 - dice_loss_val: 0.3982 - disc_loss_val: 0.2329
# Validation loss did not decrease from 1.7107.
#
# Epoch 85/151
# Batch: 1000/1000 - loss: 1.9641 - dice_loss: 0.3269 - disc_loss: 0.3295
#                loss_val: 1.5965 - dice_loss_val: 0.2787 - disc_loss_val: 0.2029
# Validation loss decresaed from 1.7107 to 1.5965. Models' weights are now saved.
#
# Epoch 86/151
# Batch: 1000/1000 - loss: 1.7024 - dice_loss: 0.2751 - disc_loss: 0.3268
#                loss_val: 2.1437 - dice_loss_val: 0.2686 - disc_loss_val: 0.8006
# Validation loss did not decrease from 1.5965.
#
# Epoch 87/151
# Batch: 1000/1000 - loss: 1.6628 - dice_loss: 0.2650 - disc_loss: 0.3379
#                loss_val: 1.6028 - dice_loss_val: 0.2602 - disc_loss_val: 0.3018
# Validation loss did not decrease from 1.5965.
#
# Epoch 88/151
# Batch: 1000/1000 - loss: 1.6293 - dice_loss: 0.2592 - disc_loss: 0.3331
#                loss_val: 1.4706 - dice_loss_val: 0.2549 - disc_loss_val: 0.1962
# Validation loss decresaed from 1.5965 to 1.4706. Models' weights are now saved.
#
# Epoch 89/151
# Batch: 1000/1000 - loss: 1.6005 - dice_loss: 0.2527 - disc_loss: 0.3368
#                loss_val: 1.5491 - dice_loss_val: 0.2552 - disc_loss_val: 0.2731
# Validation loss did not decrease from 1.4706.
#
# Epoch 90/151
# Batch: 1000/1000 - loss: 1.5997 - dice_loss: 0.2487 - disc_loss: 0.3559
#                loss_val: 1.4837 - dice_loss_val: 0.2535 - disc_loss_val: 0.2162
# Validation loss did not decrease from 1.4706.
#
# Epoch 91/151
# Batch: 1000/1000 - loss: 1.5862 - dice_loss: 0.2461 - disc_loss: 0.3556
#                loss_val: 1.4958 - dice_loss_val: 0.2486 - disc_loss_val: 0.2529
# Validation loss did not decrease from 1.4706.
#
# Epoch 92/151
# Batch: 1000/1000 - loss: 317.9183 - dice_loss: 0.2915 - disc_loss: 316.4606
#                loss_val: 2.0470 - dice_loss_val: 0.4019 - disc_loss_val: 0.0373
# Validation loss did not decrease from 1.4706.
#
# Epoch 93/151
# Batch: 1000/1000 - loss: 2.3187 - dice_loss: 0.3956 - disc_loss: 0.3406
#                loss_val: 2.0365 - dice_loss_val: 0.4019 - disc_loss_val: 0.0267
# Validation loss did not decrease from 1.4706.
#
# Epoch 94/151
# Batch: 1000/1000 - loss: 2.3683 - dice_loss: 0.3956 - disc_loss: 0.3904
#                loss_val: 2.0340 - dice_loss_val: 0.4019 - disc_loss_val: 0.0243
# Validation loss did not decrease from 1.4706.
#
# Epoch 95/151
# Batch: 1000/1000 - loss: 2.5871 - dice_loss: 0.3956 - disc_loss: 0.6093
#                loss_val: 4.5412 - dice_loss_val: 0.4019 - disc_loss_val: 2.5315
# Validation loss did not decrease from 1.4706.
#
# Epoch 96/151
# Batch: 1000/1000 - loss: 2.5790 - dice_loss: 0.3956 - disc_loss: 0.6011
#                loss_val: 2.9344 - dice_loss_val: 0.4019 - disc_loss_val: 0.9249
# Validation loss did not decrease from 1.4706.
#
# Epoch 97/151
# Batch: 1000/1000 - loss: 2.4885 - dice_loss: 0.3955 - disc_loss: 0.5112
#                loss_val: 2.0401 - dice_loss_val: 0.4019 - disc_loss_val: 0.0307
# Validation loss did not decrease from 1.4706.
#
# Epoch 98/151
# Batch: 1000/1000 - loss: 2.4490 - dice_loss: 0.3953 - disc_loss: 0.4723
#                loss_val: 2.2371 - dice_loss_val: 0.4018 - disc_loss_val: 0.2281
# Validation loss did not decrease from 1.4706.
#
# Epoch 99/151
# Batch: 1000/1000 - loss: 2.4544 - dice_loss: 0.3949 - disc_loss: 0.4801
#                loss_val: 2.2277 - dice_loss_val: 0.4012 - disc_loss_val: 0.2218
# Validation loss did not decrease from 1.4706.
#
# Epoch 100/151
# Batch: 1000/1000 - loss: 346.7377 - dice_loss: 0.3865 - disc_loss: 344.8049
#                loss_val: 2.4824 - dice_loss_val: 0.4018 - disc_loss_val: 0.4736
# Validation loss did not decrease from 1.4706.
#
# Epoch 101/151
# Batch: 1000/1000 - loss: 2.3059 - dice_loss: 0.3943 - disc_loss: 0.3346
#                loss_val: 2.4968 - dice_loss_val: 0.4002 - disc_loss_val: 0.4957
# Validation loss did not decrease from 1.4706.
#
# Epoch 102/151
# Batch: 1000/1000 - loss: 2.2056 - dice_loss: 0.3667 - disc_loss: 0.3723
#                loss_val: 1.8787 - dice_loss_val: 0.3016 - disc_loss_val: 0.3706
# Validation loss did not decrease from 1.4706.
#
# Epoch 103/151
# Batch: 1000/1000 - loss: 1.6138 - dice_loss: 0.2622 - disc_loss: 0.3026
#                loss_val: 1.6496 - dice_loss_val: 0.2519 - disc_loss_val: 0.3901
# Validation loss did not decrease from 1.4706.
#
# Epoch 104/151
# Batch: 1000/1000 - loss: 1.4818 - dice_loss: 0.2389 - disc_loss: 0.2871
#                loss_val: 1.4485 - dice_loss_val: 0.2418 - disc_loss_val: 0.2395
# Validation loss decresaed from 1.4706 to 1.4485. Models' weights are now saved.
#
# Epoch 105/151
# Batch: 1000/1000 - loss: 1.4494 - dice_loss: 0.2323 - disc_loss: 0.2880
#                loss_val: 1.3928 - dice_loss_val: 0.2377 - disc_loss_val: 0.2044
# Validation loss decresaed from 1.4485 to 1.3928. Models' weights are now saved.
#
# Epoch 106/151
# Batch: 1000/1000 - loss: 1.4313 - dice_loss: 0.2282 - disc_loss: 0.2904
#                loss_val: 1.2760 - dice_loss_val: 0.2340 - disc_loss_val: 0.1061
# Validation loss decresaed from 1.3928 to 1.2760. Models' weights are now saved.
#
# Epoch 107/151
# Batch: 1000/1000 - loss: 1.4074 - dice_loss: 0.2247 - disc_loss: 0.2840
#                loss_val: 1.2790 - dice_loss_val: 0.2304 - disc_loss_val: 0.1271
# Validation loss did not decrease from 1.2760.
#
# Epoch 108/151
# Batch: 1000/1000 - loss: 1.3884 - dice_loss: 0.2217 - disc_loss: 0.2798
#                loss_val: 1.2797 - dice_loss_val: 0.2269 - disc_loss_val: 0.1450
# Validation loss did not decrease from 1.2760.
#
# Epoch 109/151
# Batch: 1000/1000 - loss: 1.3769 - dice_loss: 0.2187 - disc_loss: 0.2834
#                loss_val: 1.2963 - dice_loss_val: 0.2241 - disc_loss_val: 0.1761
# Validation loss did not decrease from 1.2760.
#
# Epoch 110/151
# Batch: 1000/1000 - loss: 1.3845 - dice_loss: 0.2160 - disc_loss: 0.3045
#                loss_val: 1.3443 - dice_loss_val: 0.2218 - disc_loss_val: 0.2354
# Validation loss did not decrease from 1.2760.
#
# Epoch 111/151
# Batch: 1000/1000 - loss: 1.4188 - dice_loss: 0.2132 - disc_loss: 0.3529
#                loss_val: 1.1623 - dice_loss_val: 0.2189 - disc_loss_val: 0.0678
# Validation loss decresaed from 1.2760 to 1.1623. Models' weights are now saved.
#
# Epoch 112/151
# Batch: 1000/1000 - loss: 1.4045 - dice_loss: 0.2104 - disc_loss: 0.3527
#                loss_val: 1.1762 - dice_loss_val: 0.2170 - disc_loss_val: 0.0912
# Validation loss did not decrease from 1.1623.
#
# Epoch 113/151
# Batch: 1000/1000 - loss: 124.7017 - dice_loss: 0.4049 - disc_loss: 122.67751
#                loss_val: 2.0428 - dice_loss_val: 0.3681 - disc_loss_val: 0.2021
# Validation loss did not decrease from 1.1623.
#
# Epoch 114/151
# Batch: 1000/1000 - loss: 2.0198 - dice_loss: 0.3523 - disc_loss: 0.2584
#                loss_val: 1.8510 - dice_loss_val: 0.3410 - disc_loss_val: 0.1460
# Validation loss did not decrease from 1.1623.
#
# Epoch 115/151
# Batch: 1000/1000 - loss: 1.9041 - dice_loss: 0.3282 - disc_loss: 0.2630
#                loss_val: 1.8073 - dice_loss_val: 0.3199 - disc_loss_val: 0.2080
# Validation loss did not decrease from 1.1623.
#
# Epoch 116/151
# Batch: 1000/1000 - loss: 1.8350 - dice_loss: 0.3084 - disc_loss: 0.2931
#                loss_val: 1.7969 - dice_loss_val: 0.3018 - disc_loss_val: 0.2880
# Validation loss did not decrease from 1.1623.
#
# Epoch 117/151
# Batch: 1000/1000 - loss: 1.7341 - dice_loss: 0.2894 - disc_loss: 0.2872
#                loss_val: 1.6167 - dice_loss_val: 0.2876 - disc_loss_val: 0.1785
# Validation loss did not decrease from 1.1623.
#
# Epoch 118/151
# Batch: 1000/1000 - loss: 1.6274 - dice_loss: 0.2691 - disc_loss: 0.2821
#                loss_val: 1.6082 - dice_loss_val: 0.2704 - disc_loss_val: 0.2564
# Validation loss did not decrease from 1.1623.
#
# Epoch 119/151
# Batch: 1000/1000 - loss: 1.5255 - dice_loss: 0.2475 - disc_loss: 0.2879
#                loss_val: 1.2297 - dice_loss_val: 0.2437 - disc_loss_val: 0.0112
# Validation loss did not decrease from 1.1623.
#
# Epoch 120/151
# Batch: 1000/1000 - loss: 1.6732 - dice_loss: 0.2219 - disc_loss: 0.5635
#                loss_val: 4.0074 - dice_loss_val: 0.2223 - disc_loss_val: 2.8960
# Validation loss did not decrease from 1.1623.
#
# Epoch 121/151
# Batch: 1000/1000 - loss: 133.8688 - dice_loss: 0.3063 - disc_loss: 132.3375
#                loss_val: 2.2375 - dice_loss_val: 0.3997 - disc_loss_val: 0.2392
# Validation loss did not decrease from 1.1623.
#
# Epoch 122/151
# Batch: 1000/1000 - loss: 2.2543 - dice_loss: 0.3902 - disc_loss: 0.3034
#                loss_val: 2.1025 - dice_loss_val: 0.3982 - disc_loss_val: 0.1112
# Validation loss did not decrease from 1.1623.
#
# Epoch 123/151
# Batch: 1000/1000 - loss: 2.2872 - dice_loss: 0.3874 - disc_loss: 0.3502
#                loss_val: 1.9994 - dice_loss_val: 0.3933 - disc_loss_val: 0.0327
# Validation loss did not decrease from 1.1623.
#
# Epoch 124/151
# Batch: 1000/1000 - loss: 2.2548 - dice_loss: 0.3770 - disc_loss: 0.3700
#                loss_val: 1.9544 - dice_loss_val: 0.3801 - disc_loss_val: 0.0540
# Validation loss did not decrease from 1.1623.
#
# Epoch 125/151
# Batch: 1000/1000 - loss: 2.1491 - dice_loss: 0.3535 - disc_loss: 0.3816
#                loss_val: 1.7488 - dice_loss_val: 0.3460 - disc_loss_val: 0.0186
# Validation loss did not decrease from 1.1623.
#
# Epoch 126/151
# Batch: 1000/1000 - loss: 2.0480 - dice_loss: 0.3151 - disc_loss: 0.4724
#                loss_val: 1.6659 - dice_loss_val: 0.3078 - disc_loss_val: 0.1269
# Validation loss did not decrease from 1.1623.
#
# Epoch 127/151
# Batch: 1000/1000 - loss: 2.0889 - dice_loss: 0.2834 - disc_loss: 0.6718
#                loss_val: 1.6567 - dice_loss_val: 0.2786 - disc_loss_val: 0.2639
# Validation loss did not decrease from 1.1623.
#
# Epoch 128/151
# Batch: 1000/1000 - loss: 4.1014 - dice_loss: 0.2555 - disc_loss: 2.8241
#                loss_val: 1.3518 - dice_loss_val: 0.2483 - disc_loss_val: 0.1100
# Validation loss did not decrease from 1.1623.
#
# Epoch 129/151
# Batch: 1000/1000 - loss: 1.5713 - dice_loss: 0.2282 - disc_loss: 0.4305
#                loss_val: 1.1552 - dice_loss_val: 0.2257 - disc_loss_val: 0.0270
# Validation loss decresaed from 1.1623 to 1.1552. Models' weights are now saved.
#
# Epoch 130/151
# Batch: 1000/1000 - loss: 1.8212 - dice_loss: 0.2160 - disc_loss: 0.7413
#                loss_val: 1.1586 - dice_loss_val: 0.2185 - disc_loss_val: 0.0663
# Validation loss did not decrease from 1.1552.
#
# Epoch 131/151
# Batch: 1000/1000 - loss: 1.5793 - dice_loss: 0.2109 - disc_loss: 0.5248
#                loss_val: 1.2230 - dice_loss_val: 0.2177 - disc_loss_val: 0.1343
# Validation loss did not decrease from 1.1552.
#
# Epoch 132/151
# Batch: 1000/1000 - loss: 192.3378 - dice_loss: 0.3445 - disc_loss: 190.6155
#                loss_val: 3.9528 - dice_loss_val: 0.3680 - disc_loss_val: 2.1126
# Validation loss did not decrease from 1.1552.
#
# Epoch 133/151
# Batch: 1000/1000 - loss: 1.9729 - dice_loss: 0.3270 - disc_loss: 0.3379
#                loss_val: 2.1158 - dice_loss_val: 0.3115 - disc_loss_val: 0.5582
# Validation loss did not decrease from 1.1552.
#
# Epoch 134/151
# Batch: 1000/1000 - loss: 1.8010 - dice_loss: 0.2927 - disc_loss: 0.3376
#                loss_val: 2.3774 - dice_loss_val: 0.2890 - disc_loss_val: 0.9321
# Validation loss did not decrease from 1.1552.
#
# Epoch 135/151
# Batch: 1000/1000 - loss: 1.6928 - dice_loss: 0.2717 - disc_loss: 0.3342
#                loss_val: 1.9327 - dice_loss_val: 0.2676 - disc_loss_val: 0.5949
# Validation loss did not decrease from 1.1552.
#
# Epoch 136/151
# Batch: 1000/1000 - loss: 1.5351 - dice_loss: 0.2441 - disc_loss: 0.3147
#                loss_val: 2.1876 - dice_loss_val: 0.2349 - disc_loss_val: 1.0131
# Validation loss did not decrease from 1.1552.
#
# Epoch 137/151
# Batch: 1000/1000 - loss: 1.4188 - dice_loss: 0.2226 - disc_loss: 0.3060
#                loss_val: 1.8458 - dice_loss_val: 0.2199 - disc_loss_val: 0.7465
# Validation loss did not decrease from 1.1552.
#
# Epoch 138/151
# Batch: 1000/1000 - loss: 70.2770 - dice_loss: 0.3927 - disc_loss: 68.313364
#                loss_val: 2.2425 - dice_loss_val: 0.4022 - disc_loss_val: 0.2313
# Validation loss did not decrease from 1.1552.
#
# Epoch 139/151
# Batch: 1000/1000 - loss: 2.5575 - dice_loss: 0.3958 - disc_loss: 0.5787
#                loss_val: 2.3312 - dice_loss_val: 0.4019 - disc_loss_val: 0.3219
# Validation loss did not decrease from 1.1552.
#
# Epoch 140/151
# Batch: 1000/1000 - loss: 2.4919 - dice_loss: 0.3945 - disc_loss: 0.5196
#                loss_val: 2.2471 - dice_loss_val: 0.3988 - disc_loss_val: 0.2533
# Validation loss did not decrease from 1.1552.
#
# Epoch 141/151
# Batch: 1000/1000 - loss: 2.0236 - dice_loss: 0.3245 - disc_loss: 0.4011
#                loss_val: 1.3275 - dice_loss_val: 0.2551 - disc_loss_val: 0.0522
# Validation loss did not decrease from 1.1552.
#
# Epoch 142/151
# Batch: 1000/1000 - loss: 1.5271 - dice_loss: 0.2352 - disc_loss: 0.3510
#                loss_val: 1.2195 - dice_loss_val: 0.2276 - disc_loss_val: 0.0817
# Validation loss did not decrease from 1.1552.
#
# Epoch 143/151
# Batch: 1000/1000 - loss: 233.0363 - dice_loss: 0.2401 - disc_loss: 231.8360
#                loss_val: 2.3107 - dice_loss_val: 0.4029 - disc_loss_val: 0.2963
# Validation loss did not decrease from 1.1552.
#
# Epoch 144/151
# Batch: 1000/1000 - loss: 2.3330 - dice_loss: 0.3962 - disc_loss: 0.3521
#                loss_val: 2.5389 - dice_loss_val: 0.4026 - disc_loss_val: 0.5260
# Validation loss did not decrease from 1.1552.
#
# Epoch 145/151
# Batch: 1000/1000 - loss: 2.4302 - dice_loss: 0.3961 - disc_loss: 0.4496
#                loss_val: 2.3511 - dice_loss_val: 0.4024 - disc_loss_val: 0.3393
# Validation loss did not decrease from 1.1552.
#
# Epoch 146/151
# Batch: 1000/1000 - loss: 2.4781 - dice_loss: 0.3961 - disc_loss: 0.4978
#                loss_val: 2.3074 - dice_loss_val: 0.4022 - disc_loss_val: 0.2965
# Validation loss did not decrease from 1.1552.
#
# Epoch 147/151
# Batch: 1000/1000 - loss: 2.4704 - dice_loss: 0.3951 - disc_loss: 0.4947
#                loss_val: 2.4452 - dice_loss_val: 0.3933 - disc_loss_val: 0.4786
# Validation loss did not decrease from 1.1552.
#
# Epoch 148/151
# Batch: 1000/1000 - loss: 1.9646 - dice_loss: 0.3242 - disc_loss: 0.3435
#                loss_val: 1.8329 - dice_loss_val: 0.3131 - disc_loss_val: 0.2673
# Validation loss did not decrease from 1.1552.
#
# Epoch 149/151
# Batch: 1000/1000 - loss: 1.5348 - dice_loss: 0.2451 - disc_loss: 0.3091
#                loss_val: 1.3016 - dice_loss_val: 0.2213 - disc_loss_val: 0.1951
# Validation loss did not decrease from 1.1552.
#
# Epoch 150/151
# Batch: 1000/1000 - loss: 1.3909 - dice_loss: 0.2120 - disc_loss: 0.3310
#                loss_val: 1.2116 - dice_loss_val: 0.2160 - disc_loss_val: 0.1317
# Validation loss did not decrease from 1.1552.
#
# Epoch 151/151
# Batch: 1000/1000 - loss: 1.4375 - dice_loss: 0.2069 - disc_loss: 0.4030
#                loss_val: 1.4636 - dice_loss_val: 0.2126 - disc_loss_val: 0.4004
# Validation loss did not decrease from 1.1552.
#
# 186515.64315581322
