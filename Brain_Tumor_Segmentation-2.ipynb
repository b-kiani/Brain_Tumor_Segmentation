# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import os
import cv2
import tarfile
import warnings
import glob
import time
import numpy as np
import nibabel as nib
import pandas as pd
from sys import stdout
import matplotlib.pyplot as plt
import matplotlib.image as mpim
from scipy.ndimage.interpolation import affine_transform
from sklearn.model_selection import train_test_split
from skimage.util import montage 
from skimage.transform import rotate
from ipywidgets import interact, interactive, IntSlider, ToggleButtons

import tensorflow as tf
from tensorflow import keras
print('tf',tf.__version__)
print('keras',keras.__version__)
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Flatten, Conv3D, Conv3DTranspose, Dropout, ReLU, LeakyReLU, PReLU, ELU,
                                     Concatenate, Activation, ZeroPadding3D, MaxPooling3D, UpSampling3D)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.utils import plot_model, to_categorical
import tensorflow_addons as tfa
from tensorflow_addons.layers import InstanceNormalization
from tensorflow_addons.layers import GroupNormalization
from tensorflow_addons.layers import SpectralNormalization
warnings.filterwarnings("ignore")
plt.rcdefaults()

# Parameters
TRAIN_DATASET_PATH = './brain_images'
VALIDATION_DATASET_PATH = './val_brain_images'

SEGMENT_CLASSES = {
    0 : 'NOT tumor', # or Normal
    1 : 'NECROTIC/CORE', # or NON-ENHANCING tumor (CORE)
    2 : 'EDEMA',
    3 : 'ENHANCING' # original 4 -> converted into 3 later
}

VOLUME_SLICES = 128 
VOLUME_START_AT = 22
IMG_SIZE = 128
KERNEL_SIZE = 4
KERNEL_INIT = 'he_normal'
PAD='same'
DROP_RATE = 0.25
# Out:
# tf 2.8.0
# keras 2.8.0

# %% [markdown]
# ##Unzipping

# %%
start = time.time()
tar = tarfile.open('archive/BraTS2021_Training_Data.tar')
tar.extractall('./brain_images')
tar.close()
end = time.time()
total_time = end - start
print(total_time)
# Out:
# 14.20097279548645

# %%
# !mkdir val_brain_images

# %%
tar = tarfile.open('/content/brats-2021-task1/BraTS2021_00621.tar')
tar.extractall('./val_brain_images')
tar.close()

# %%
tar = tarfile.open('/content/brats-2021-task1/BraTS2021_00495.tar')
tar.extractall('./val_brain_images')
tar.close()

# %% [markdown]
# ##Visualization

# %%
image_path = "./brain_images/BraTS2021_00284/BraTS2021_00284_t1.nii.gz"
t1_obj = nib.load(image_path)
print(type(t1_obj))
image_data = t1_obj.get_fdata()
print(type(image_data))
image_data.shape
# Out:
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'numpy.ndarray'>
# (240, 240, 155)

# %%
t1_hdr = t1_obj.header
print(t1_hdr)
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 0
# dim             : [  3 240 240 155   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [1. 1. 1. 1. 0. 0. 0. 0.]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 2
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b''
# aux_file        : b''
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.0
# quatern_c       : 0.0
# quatern_d       : 1.0
# qoffset_x       : 0.0
# qoffset_y       : 239.0
# qoffset_z       : 0.0
# srow_x          : [-1. -0. -0.  0.]
# srow_y          : [ -0.  -1.  -0. 239.]
# srow_z          : [0. 0. 1. 0.]
# intent_name     : b''
# magic           : b'n+1'

# %%
x_slice = image_data[59, :, :]
y_slice = image_data[:, 54, :]
z_slice = image_data[:, :, 64]
slices = [x_slice, y_slice, z_slice]

fig, axes = plt.subplots(1, len(slices))
for i, slice in enumerate(slices):
    axes[i].imshow(slice.T, cmap="gray", origin="lower")
    axes[i].axis('off')

# %%
def visualize_3d(layer):
    plt.figure(figsize=(10, 5))
    plt.imshow(image_data[:, :, layer], cmap='gray');#cmap='bone'
    plt.axis('off')
    return layer

interact(visualize_3d, layer=(0, image_data.shape[2] - 1));
# Out:
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…

# %%
layer = 50

def visualize_3d_labels(layer):
    mask = nib.load('./brain_images/BraTS2021_00284/BraTS2021_00284_seg.nii.gz').get_fdata()
    plt.imshow(mask[:,:,layer], cmap="bone")
    plt.axis('off')
    plt.tight_layout()

interact(visualize_3d_labels, layer=(0, image_data.shape[2] - 1));
# Out:
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…

# %%
layer = 50

def visualize_3d_labels(layer):
    mask = nib.load('./brain_images/BraTS2021_00284/BraTS2021_00284_seg.nii.gz').get_fdata()
    color_segmentation = np.zeros((240,240,3))
    gray_segmentation = mask[:,:,layer]
    color_segmentation[gray_segmentation == 1] = [255,0,0] # Red (necrotic tumor core)
    color_segmentation[gray_segmentation == 2] = [0,255,0] # Green (peritumoral edematous/invaded tissue)
    color_segmentation[gray_segmentation == 4] = [0,0,255] # Blue (enhancing tumor)
    plt.imshow(color_segmentation, cmap="gray") #cmap="bone"
    plt.axis('off')
    plt.tight_layout()

interact(visualize_3d_labels, layer=(0, image_data.shape[2] - 1));
# Out:
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (20,20))
ax1.imshow(rotate(montage(image_data[:,:,:]), 90, resize=True), cmap ='bone') #cmap ='gray'

# %%
mask = nib.load('./brain_images/BraTS2021_00284/BraTS2021_00284_seg.nii.gz').get_fdata()
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(mask[60:-60,:,:]), 90, resize=True), cmap ='bone')

# %%
# %cd /content/brain_images

img_ids = ["00376", "00789", "00441", "00703", "00807", "00523", "00241", "00778"]
SCAN_NUM = 83

for img_id in img_ids:
    plt.figure(figsize=(18, 5))

    for i, nii in enumerate([f'./BraTS2021_{img_id}/BraTS2021_{img_id}_{s_type}.nii.gz' for s_type in ["flair", "t1", "t1ce", "t2", "seg"]]):
        plt.subplot(1,5,i+1)
        image = nib.load(nii).get_fdata()
        plt.title(nii.rsplit("_", 1)[1].split(".", 1)[0], fontweight="bold")
        plt.axis(False)
        plt.imshow(image[:, :, SCAN_NUM], cmap="bone")
        
    plt.tight_layout()    
    plt.show()

# %cd /content

# %% [markdown]
# ##Data Split by using Holdout Method

# %%
def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
    return x

train_and_val_directories = [f.path for f in os.scandir(TRAIN_DATASET_PATH) if f.is_dir()]
train_and_test_ids = pathListIntoIds(train_and_val_directories); 

train_ids, val_ids = train_test_split(train_and_test_ids,test_size=0.2) #test_size=0.25

# %% [markdown]
# ##Data Generator

# %%
class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE), batch_size = 1, n_channels = 4, shuffle=True):
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):

        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        Batch_ids = [self.list_IDs[k] for k in indexes]

        X, y = self.__data_generation(Batch_ids)
        
        return X, y

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels)) # X : (n_samples, *dim, n_channels)
        y = np.zeros((self.batch_size*VOLUME_SLICES, 128, 128))

        
        # data
        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATASET_PATH, i)

            data_path = os.path.join(case_path, f'{i}_flair.nii.gz');
            flair = nib.load(data_path).get_fdata()    

            data_path = os.path.join(case_path, f'{i}_t1ce.nii.gz');
            ce = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_t1.nii.gz');
            t1 = nib.load(data_path).get_fdata()    

            data_path = os.path.join(case_path, f'{i}_t2.nii.gz');
            t2 = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_seg.nii.gz');
            seg = nib.load(data_path).get_fdata()
        
            for j in range(VOLUME_SLICES):
             X[j+(VOLUME_SLICES*c),:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

             X[j+(VOLUME_SLICES*c),:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

             X[j+(VOLUME_SLICES*c),:,:,2] = cv2.resize(t1[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

             X[j+(VOLUME_SLICES*c),:,:,3] = cv2.resize(t2[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))             
             
             y[j +VOLUME_SLICES*c,:,:] = cv2.resize(seg[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

        X = X.reshape(1,128,128,128,4)
        y = y.reshape(1,128,128,128)

        # masks
        y[y==4] = 3;
        y = tf.one_hot(y, 4);

        return X/np.max(X), y

# %%
training_generator = DataGenerator(train_ids)
print(training_generator[0][0].shape)
valid_generator = DataGenerator(val_ids)
# Out:
# 2022-05-27 21:08:24.904411: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (1, 128, 128, 128, 4)
# 2022-05-27 21:08:26.704873: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46712 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:3b:00.0, compute capability: 8.6
# 2022-05-27 21:08:26.705497: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46712 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:5e:00.0, compute capability: 8.6
# 2022-05-27 21:08:26.705930: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46712 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:86:00.0, compute capability: 8.6
# 2022-05-27 21:08:26.706394: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 46121 MB memory:  -> device: 3, name: NVIDIA RTX A6000, pci bus id: 0000:af:00.0, compute capability: 8.6

# %% [markdown]
# ##3D GAN Model

# %%
# Optimizers
generator_optimizer = Adam(2e-4, beta_1=0.5)
discriminator_optimizer = Adam(2e-4, beta_1=0.5)

# %% [markdown]
# ###Generator

# %%
def Gen():
################## Encoder ##################
  inputs = Input((128,128,128,4), name='input_image')
# Block 1
  x = Conv3D(64, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(inputs)
  x = Conv3D(64, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = ELU()(x)
  x = MaxPooling3D(pool_size=2, strides=2, name='MP1')(x)
  D1 = Dropout(DROP_RATE)(x)
# Block 2
  x = Conv3D(128, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(D1)
  x = GroupNormalization(groups=4, axis=4)(x)
  x = Conv3D(128, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = ELU()(x)
  x = MaxPooling3D(pool_size=2, strides=2, name='MP2')(x)
  D2 = Dropout(DROP_RATE)(x)
# Block 3
  x = Conv3D(192, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(D2)
  x = GroupNormalization(groups=4, axis=4)(x)
  x = Conv3D(192, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = ELU()(x)
  x = MaxPooling3D(pool_size=2, strides=2, name='MP3')(x)
  D3 = Dropout(DROP_RATE)(x)

# bottlenek
  # base
  x = Conv3D(256, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(D3)
  x = GroupNormalization(groups=4, axis=4)(x)
  x = Conv3D(256, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = ELU()(x)
  x = MaxPooling3D(pool_size=2, strides=2, name='MP4')(x)

  #1
  y = Conv3D(256, kernel_size=KERNEL_SIZE, strides=1, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = GroupNormalization(groups=4, axis=4)(y)
  x = Conv3D(256, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = ELU()(x)
  x = Concatenate()([x, y])

  #2
  y = Conv3D(256, kernel_size=KERNEL_SIZE, strides=1, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = GroupNormalization(groups=4, axis=4)(y)
  x = Conv3D(256, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = ELU()(x)
  x = Concatenate()([x, y])

  #3
  y = Conv3D(256, kernel_size=KERNEL_SIZE, strides=1, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = GroupNormalization(groups=4, axis=4)(y)
  x = Conv3D(256, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = ELU()(x)
  x = Concatenate()([x, y])

  #4
  y = Conv3D(256, kernel_size=KERNEL_SIZE, strides=1, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = GroupNormalization(groups=4, axis=4)(y)
  x = Conv3D(256, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = ELU()(x)
  x = Concatenate()([x, y])


################## Decoder ##################
  x = Conv3DTranspose(64, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = GroupNormalization(groups=4, axis=4)(x)
  x = Conv3DTranspose(64, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = ELU()(x)
  x = UpSampling3D(size=2)(x)
  x = Concatenate()([x, D3])
  x = Dropout(DROP_RATE)(x)

  x = Conv3DTranspose(64, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = GroupNormalization(groups=4, axis=4)(x)
  x = Conv3DTranspose(64, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = ELU()(x)
  x = UpSampling3D(size=2)(x)
  x = Concatenate()([x, D2])
  x = Dropout(DROP_RATE)(x)

  x = Conv3DTranspose(64, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = GroupNormalization(groups=4, axis=4)(x)
  x = Conv3DTranspose(64, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding=PAD)(x)
  x = ELU()(x)
  x = UpSampling3D(size=2)(x)
  x = Concatenate()([x, D1])
  x = Dropout(DROP_RATE)(x)


################## Output ##################
  out = Conv3DTranspose(4, kernel_size=KERNEL_SIZE, strides=2, kernel_initializer=KERNEL_INIT, padding=PAD, name='Gen_Output')(x)
  out = Activation('softmax')(out)
  return Model(inputs=inputs, outputs=out, name='Generator')

# %%
gen = Gen()
gen.summary(positions=[.33, .6, .7, 1.])
# Out:
# Model: "Generator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape              Param #   Connected to
# ==================================================================================================
#  input_image (InputLayer)       [(None, 128, 128, 128, 4  0         []
#                                 )]
#
#  conv3d (Conv3D)                (None, 128, 128, 128, 64  16448     ['input_image[0][0]']
#                                 )
#
#  conv3d_1 (Conv3D)              (None, 128, 128, 128, 64  262208    ['conv3d[0][0]']
#                                 )
#
#  elu (ELU)                      (None, 128, 128, 128, 64  0         ['conv3d_1[0][0]']
#                                 )
#
#  MP1 (MaxPooling3D)             (None, 64, 64, 64, 64)    0         ['elu[0][0]']
#
#  dropout (Dropout)              (None, 64, 64, 64, 64)    0         ['MP1[0][0]']
#
#  conv3d_2 (Conv3D)              (None, 64, 64, 64, 128)   524416    ['dropout[0][0]']
#
#  group_normalization (GroupNorm  (None, 64, 64, 64, 128)  256       ['conv3d_2[0][0]']
#  alization)
#
#  conv3d_3 (Conv3D)              (None, 64, 64, 64, 128)   1048704   ['group_normalization[0][0]']
#
#  elu_1 (ELU)                    (None, 64, 64, 64, 128)   0         ['conv3d_3[0][0]']
#
#  MP2 (MaxPooling3D)             (None, 32, 32, 32, 128)   0         ['elu_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 32, 32, 32, 128)   0         ['MP2[0][0]']
#
#  conv3d_4 (Conv3D)              (None, 32, 32, 32, 192)   1573056   ['dropout_1[0][0]']
#
#  group_normalization_1 (GroupNo  (None, 32, 32, 32, 192)  384       ['conv3d_4[0][0]']
#  rmalization)
#
#  conv3d_5 (Conv3D)              (None, 32, 32, 32, 192)   2359488   ['group_normalization_1[0][0]'
#                                                                     ]
#
#  elu_2 (ELU)                    (None, 32, 32, 32, 192)   0         ['conv3d_5[0][0]']
#
#  MP3 (MaxPooling3D)             (None, 16, 16, 16, 192)   0         ['elu_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 16, 16, 16, 192)   0         ['MP3[0][0]']
#
#  conv3d_6 (Conv3D)              (None, 16, 16, 16, 256)   3145984   ['dropout_2[0][0]']
#
#  group_normalization_2 (GroupNo  (None, 16, 16, 16, 256)  512       ['conv3d_6[0][0]']
#  rmalization)
#
#  conv3d_7 (Conv3D)              (None, 16, 16, 16, 256)   4194560   ['group_normalization_2[0][0]'
#                                                                     ]
#
#  elu_3 (ELU)                    (None, 16, 16, 16, 256)   0         ['conv3d_7[0][0]']
#
#  MP4 (MaxPooling3D)             (None, 8, 8, 8, 256)      0         ['elu_3[0][0]']
#
#  conv3d_8 (Conv3D)              (None, 8, 8, 8, 256)      4194560   ['MP4[0][0]']
#
#  group_normalization_3 (GroupNo  (None, 8, 8, 8, 256)     512       ['conv3d_8[0][0]']
#  rmalization)
#
#  conv3d_9 (Conv3D)              (None, 8, 8, 8, 256)      4194560   ['group_normalization_3[0][0]'
#                                                                     ]
#
#  elu_4 (ELU)                    (None, 8, 8, 8, 256)      0         ['conv3d_9[0][0]']
#
#  concatenate (Concatenate)      (None, 8, 8, 8, 512)      0         ['elu_4[0][0]',
#                                                                      'conv3d_8[0][0]']
#
#  conv3d_10 (Conv3D)             (None, 8, 8, 8, 256)      8388864   ['concatenate[0][0]']
#
#  group_normalization_4 (GroupNo  (None, 8, 8, 8, 256)     512       ['conv3d_10[0][0]']
#  rmalization)
#
#  conv3d_11 (Conv3D)             (None, 8, 8, 8, 256)      4194560   ['group_normalization_4[0][0]'
#                                                                     ]
#
#  elu_5 (ELU)                    (None, 8, 8, 8, 256)      0         ['conv3d_11[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 8, 512)      0         ['elu_5[0][0]',
#                                                                      'conv3d_10[0][0]']
#
#  conv3d_12 (Conv3D)             (None, 8, 8, 8, 256)      8388864   ['concatenate_1[0][0]']
#
#  group_normalization_5 (GroupNo  (None, 8, 8, 8, 256)     512       ['conv3d_12[0][0]']
#  rmalization)
#
#  conv3d_13 (Conv3D)             (None, 8, 8, 8, 256)      4194560   ['group_normalization_5[0][0]'
#                                                                     ]
#
#  elu_6 (ELU)                    (None, 8, 8, 8, 256)      0         ['conv3d_13[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 8, 8, 8, 512)      0         ['elu_6[0][0]',
#                                                                      'conv3d_12[0][0]']
#
#  conv3d_14 (Conv3D)             (None, 8, 8, 8, 256)      8388864   ['concatenate_2[0][0]']
#
#  group_normalization_6 (GroupNo  (None, 8, 8, 8, 256)     512       ['conv3d_14[0][0]']
#  rmalization)
#
#  conv3d_15 (Conv3D)             (None, 8, 8, 8, 256)      4194560   ['group_normalization_6[0][0]'
#                                                                     ]
#
#  elu_7 (ELU)                    (None, 8, 8, 8, 256)      0         ['conv3d_15[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 8, 8, 8, 512)      0         ['elu_7[0][0]',
#                                                                      'conv3d_14[0][0]']
#
#  conv3d_transpose (Conv3DTransp  (None, 8, 8, 8, 64)      2097216   ['concatenate_3[0][0]']
#  ose)
#
#  group_normalization_7 (GroupNo  (None, 8, 8, 8, 64)      128       ['conv3d_transpose[0][0]']
#  rmalization)
#
#  conv3d_transpose_1 (Conv3DTran  (None, 8, 8, 8, 64)      262208    ['group_normalization_7[0][0]'
#  spose)                                                             ]
#
#  elu_8 (ELU)                    (None, 8, 8, 8, 64)       0         ['conv3d_transpose_1[0][0]']
#
#  up_sampling3d (UpSampling3D)   (None, 16, 16, 16, 64)    0         ['elu_8[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 16, 16, 16, 256)   0         ['up_sampling3d[0][0]',
#                                                                      'dropout_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 16, 16, 16, 256)   0         ['concatenate_4[0][0]']
#
#  conv3d_transpose_2 (Conv3DTran  (None, 16, 16, 16, 64)   1048640   ['dropout_3[0][0]']
#  spose)
#
#  group_normalization_8 (GroupNo  (None, 16, 16, 16, 64)   128       ['conv3d_transpose_2[0][0]']
#  rmalization)
#
#  conv3d_transpose_3 (Conv3DTran  (None, 16, 16, 16, 64)   262208    ['group_normalization_8[0][0]'
#  spose)                                                             ]
#
#  elu_9 (ELU)                    (None, 16, 16, 16, 64)    0         ['conv3d_transpose_3[0][0]']
#
#  up_sampling3d_1 (UpSampling3D)  (None, 32, 32, 32, 64)   0         ['elu_9[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 32, 192)   0         ['up_sampling3d_1[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dropout_4 (Dropout)            (None, 32, 32, 32, 192)   0         ['concatenate_5[0][0]']
#
#  conv3d_transpose_4 (Conv3DTran  (None, 32, 32, 32, 64)   786496    ['dropout_4[0][0]']
#  spose)
#
#  group_normalization_9 (GroupNo  (None, 32, 32, 32, 64)   128       ['conv3d_transpose_4[0][0]']
#  rmalization)
#
#  conv3d_transpose_5 (Conv3DTran  (None, 32, 32, 32, 64)   262208    ['group_normalization_9[0][0]'
#  spose)                                                             ]
#
#  elu_10 (ELU)                   (None, 32, 32, 32, 64)    0         ['conv3d_transpose_5[0][0]']
#
#  up_sampling3d_2 (UpSampling3D)  (None, 64, 64, 64, 64)   0         ['elu_10[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 64, 128)   0         ['up_sampling3d_2[0][0]',
#                                                                      'dropout[0][0]']
#
#  dropout_5 (Dropout)            (None, 64, 64, 64, 128)   0         ['concatenate_6[0][0]']
#
#  Gen_Output (Conv3DTranspose)   (None, 128, 128, 128, 4)  32772     ['dropout_5[0][0]']
#  activation (Activation)        (None, 128, 128, 128, 4)  0         ['Gen_Output[0][0]']
#
# ==================================================================================================
# Total params: 64,019,588
# Trainable params: 64,019,588
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(gen, to_file='gen_model.png', show_shapes=True, dpi=100)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %% [markdown]
# ###Discriminator

# %%
def Disc():
  inputs = Input((128,128,128,4), name='input_image')
  targets = Input((128,128,128,4), name='target_image')
  x = Concatenate()([inputs, targets])

# Block 1
  x = Conv3D(64, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding='same', name='C1')(x)
  x = ELU()(x)
  x = MaxPooling3D(pool_size=2, strides=2, name='MP1')(x)
  D1 = Dropout(DROP_RATE, name='D1')(x)

# Block 2
  x = SpectralNormalization(Conv3D(128, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding='same', name='C2'))(D1)
  x = ELU()(x)
  x = MaxPooling3D(pool_size=2, strides=2, name='MP2')(x)
  D2 = Dropout(DROP_RATE, name='D2')(x)

# Block 3
  x = SpectralNormalization(Conv3D(256, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding='same', name='C3'))(D2)
  x = ELU()(x)
  x = MaxPooling3D(pool_size=2, strides=2, name='MP3')(x)
  D3 = Dropout(DROP_RATE, name='D3')(x)
  x = ZeroPadding3D()(D3)

# Block 4
  x = SpectralNormalization(Conv3D(512, kernel_size=KERNEL_SIZE, strides=1, dilation_rate=2, kernel_initializer=KERNEL_INIT, padding='same', name='C4'))(x)
  x = ELU()(x)
  x = MaxPooling3D(pool_size=2, strides=2, name='MP4')(x)   
  x = ZeroPadding3D()(x)

  out = Conv3D(1, kernel_size=KERNEL_SIZE, strides=1, padding='valid', kernel_initializer=KERNEL_INIT, name='disc_output')(x) 

  return Model(inputs=[targets, inputs], outputs=out, name='Discriminator')

# %%
disc = Disc()
disc.summary(positions=[.33, .6, .7, 1.])
# Out:
# Model: "Discriminator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape              Param #   Connected to
# ==================================================================================================
#  input_image (InputLayer)       [(None, 128, 128, 128, 4  0         []
#                                 )]
#
#  target_image (InputLayer)      [(None, 128, 128, 128, 4  0         []
#                                 )]
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 128, 8)  0         ['input_image[0][0]',
#                                                                      'target_image[0][0]']
#
#  C1 (Conv3D)                    (None, 128, 128, 128, 64  32832     ['concatenate_7[0][0]']
#                                 )
#
#  elu_11 (ELU)                   (None, 128, 128, 128, 64  0         ['C1[0][0]']
#                                 )
#
#  MP1 (MaxPooling3D)             (None, 64, 64, 64, 64)    0         ['elu_11[0][0]']
#
#  D1 (Dropout)                   (None, 64, 64, 64, 64)    0         ['MP1[0][0]']
#
#  spectral_normalization (Spectr  (None, 64, 64, 64, 128)  524544    ['D1[0][0]']
#  alNormalization)
#
#  elu_12 (ELU)                   (None, 64, 64, 64, 128)   0         ['spectral_normalization[0][0]
#                                                                     ']
#
#  MP2 (MaxPooling3D)             (None, 32, 32, 32, 128)   0         ['elu_12[0][0]']
#
#  D2 (Dropout)                   (None, 32, 32, 32, 128)   0         ['MP2[0][0]']
#
#  spectral_normalization_1 (Spec  (None, 32, 32, 32, 256)  2097664   ['D2[0][0]']
#  tralNormalization)
#
#  elu_13 (ELU)                   (None, 32, 32, 32, 256)   0         ['spectral_normalization_1[0][
#                                                                     0]']
#
#  MP3 (MaxPooling3D)             (None, 16, 16, 16, 256)   0         ['elu_13[0][0]']
#
#  D3 (Dropout)                   (None, 16, 16, 16, 256)   0         ['MP3[0][0]']
#
#  zero_padding3d (ZeroPadding3D)  (None, 18, 18, 18, 256)  0         ['D3[0][0]']
#
#  spectral_normalization_2 (Spec  (None, 18, 18, 18, 512)  8389632   ['zero_padding3d[0][0]']
#  tralNormalization)
#
#  elu_14 (ELU)                   (None, 18, 18, 18, 512)   0         ['spectral_normalization_2[0][
#                                                                     0]']
#
#  MP4 (MaxPooling3D)             (None, 9, 9, 9, 512)      0         ['elu_14[0][0]']
#
#  zero_padding3d_1 (ZeroPadding3  (None, 11, 11, 11, 512)  0         ['MP4[0][0]']
#  D)
#
#  disc_output (Conv3D)           (None, 8, 8, 8, 1)        32769     ['zero_padding3d_1[0][0]']
#
# ==================================================================================================
# Total params: 11,077,441
# Trainable params: 11,076,545
# Non-trainable params: 896
# __________________________________________________________________________________________________

# %%
plot_model(disc, to_file='disc_model.png', show_shapes=True, dpi=100)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %% [markdown]
# ##Losses
# ref:
# https://arxiv.org/pdf/1606.04797v1.pdf
#
# https://arxiv.org/abs/2112.13054

# %%
class_weights = np.array([0.25659472, 45.465614, 16.543337, 49.11155], dtype='float32')

def diceLoss(y_true, y_pred, class_weights):
    '''Dice = (2*|X & Y|)/ (|X|+ |Y|) = 2*sum(|A*B|)/(sum(A^2)+sum(B^2))'''
    y_true = tf.convert_to_tensor(y_true, 'float32')
    y_pred = tf.convert_to_tensor(y_pred, y_true.dtype)

    num = tf.math.reduce_sum(tf.math.multiply(class_weights, tf.math.reduce_sum(tf.math.multiply(y_true, y_pred), axis=[0,1,2,3])))
    den = tf.math.reduce_sum(tf.math.multiply(class_weights, tf.math.reduce_sum(tf.math.add(y_true, y_pred), axis=[0,1,2,3])))+1e-5

    return 1-2*num/den

def discriminator_loss(disc_real_output, disc_fake_output):
    real_loss = tf.math.reduce_mean(tf.math.pow(tf.ones_like(disc_real_output) - disc_real_output, 2))
    fake_loss = tf.math.reduce_mean(tf.math.pow(tf.zeros_like(disc_fake_output) - disc_fake_output, 2))

    disc_loss = 0.5*(real_loss + fake_loss)

    return disc_loss


def generator_loss(target, gen_output, disc_fake_output, class_weights, alpha):
    
    # dice loss
    dice_loss = diceLoss(target, gen_output, class_weights)
    
    # disc loss
    disc_loss = tf.math.reduce_mean(tf.math.pow(tf.ones_like(disc_fake_output) - disc_fake_output, 2))
       
    # total loss
    gen_loss = alpha*dice_loss + disc_loss

    return gen_loss, dice_loss, disc_loss

# %% [markdown]
# ##Training Function

# %%
@tf.function
def train_step(image, target, alpha):
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:

        gen_output = gen(image, training=True)

        disc_real_output = disc([image, target], training=True)
        disc_fake_output = disc([image, gen_output], training=True)
        disc_loss = discriminator_loss(disc_real_output, disc_fake_output)
        
        gen_loss, dice_loss, disc_loss_gen = generator_loss(target, gen_output, disc_fake_output, class_weights, alpha)
    # Calculate the gradients
    generator_gradients = gen_tape.gradient(gen_loss, gen.trainable_variables)
    discriminator_gradients = disc_tape.gradient(disc_loss, disc.trainable_variables)
    # Apply the gradients
    generator_optimizer.apply_gradients(zip(generator_gradients, gen.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(discriminator_gradients, disc.trainable_variables))
        
    return gen_loss, dice_loss, disc_loss_gen
        
@tf.function
def test_step(image, target, alpha):
    gen_output = gen(image, training=False)

    disc_real_output = disc([image, target], training=False)
    disc_fake_output = disc([image, gen_output], training=False)
    disc_loss = discriminator_loss(disc_real_output, disc_fake_output)

    gen_loss, dice_loss, disc_loss_gen = generator_loss(target, gen_output, disc_fake_output, class_weights, alpha)
        
    return gen_loss, dice_loss, disc_loss_gen

def fit(train_gen, valid_gen, alpha, epochs):
    # path = './RESULTS' #saving in content
    path = 'Results_newcode' ##saving in drive
    if os.path.exists(path)==False:
        os.mkdir(path)
        
    Nt = len(train_gen)
    history = {'train': [], 'valid': []}
    prev_loss = np.inf
    
    epoch_v2v_loss = tf.keras.metrics.Mean()
    epoch_dice_loss = tf.keras.metrics.Mean()
    epoch_disc_loss = tf.keras.metrics.Mean()
    epoch_v2v_loss_val = tf.keras.metrics.Mean()
    epoch_dice_loss_val = tf.keras.metrics.Mean()
    epoch_disc_loss_val = tf.keras.metrics.Mean()
    
    for e in range(epochs):
        print('Epoch {}/{}'.format(e+1,epochs))
        b = 0
        for Xb, yb in train_gen:
            b += 1
            losses = train_step(Xb, yb, alpha)
            epoch_v2v_loss.update_state(losses[0])
            epoch_dice_loss.update_state(losses[1])
            epoch_disc_loss.update_state(losses[2])
            # epoch_m_iou.update_state()
            
            stdout.write('\rBatch: {}/{} - loss: {:.4f} - dice_loss: {:.4f} - disc_loss: {:.4f}'
                         .format(b, Nt, epoch_v2v_loss.result(), epoch_dice_loss.result(), epoch_disc_loss.result()))
            stdout.flush()
        history['train'].append([epoch_v2v_loss.result(), epoch_dice_loss.result(), epoch_disc_loss.result()])
        
        for Xb, yb in valid_gen:
            losses_val = test_step(Xb, yb, alpha)
            epoch_v2v_loss_val.update_state(losses_val[0])
            epoch_dice_loss_val.update_state(losses_val[1])
            epoch_disc_loss_val.update_state(losses_val[2])
            
        stdout.write('\n               loss_val: {:.4f} - dice_loss_val: {:.4f} - disc_loss_val: {:.4f}'
                     .format(epoch_v2v_loss_val.result(), epoch_dice_loss_val.result(), epoch_disc_loss_val.result()))
        stdout.flush()
        history['valid'].append([epoch_v2v_loss_val.result(), epoch_dice_loss_val.result(), epoch_disc_loss_val.result()])
        
        # save pred image at epoch e 
        y_pred = gen.predict(Xb)
        y_true = np.argmax(yb, axis=-1)
        y_pred = np.argmax(y_pred, axis=-1)

        canvas = np.zeros((128, 128*3))
        idx = np.random.randint(len(Xb))
        
        x = Xb[idx,:,:,64,2] 
        canvas[0:128, 0:128] = (x - np.min(x))/(np.max(x)-np.min(x)+1e-6)
        canvas[0:128, 128:2*128] = y_true[idx,:,:,64]/3
        canvas[0:128, 2*128:3*128] = y_pred[idx,:,:,64]/3
        
        fname = (path + '/pred@epoch_{:03d}.png').format(e+1)
        mpim.imsave(fname, canvas, cmap='gray')
        
        # save models
        print(' ')
        if epoch_v2v_loss_val.result() < prev_loss:    
            gen.save_weights(path + '/Generator.h5') 
            disc.save_weights(path + '/Discriminator.h5')
            print("Validation loss decresaed from {:.4f} to {:.4f}. Models' weights are now saved.".format(prev_loss, epoch_v2v_loss_val.result()))
            prev_loss = epoch_v2v_loss_val.result()
        else:
            print("Validation loss did not decrease from {:.4f}.".format(prev_loss))
        print(' ')
        
        # resets losses states
        epoch_v2v_loss.reset_states()
        epoch_dice_loss.reset_states()
        epoch_disc_loss.reset_states()
        epoch_v2v_loss_val.reset_states()
        epoch_dice_loss_val.reset_states()
        epoch_disc_loss_val.reset_states()
        
        del Xb, yb, canvas, y_pred, y_true, idx
        
    return history

# %%
# Load saved Model
# gen.load_weights('/content/drive/MyDrive/RESULTS-2/Generator.h5')
# disc.load_weights('/content/drive/MyDrive/RESULTS-2/Discriminator.h5')

# %% [markdown]
# ##Training and Testing

# %%
start = time.time()
alpha = 5
n_epochs = 500
h = fit(training_generator, valid_generator, alpha, n_epochs)
end = time.time()
total_time = end - start
print(total_time)
# Out:
# Epoch 1/500
# 2022-05-27 21:08:38.356106: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2022-05-27 21:08:39.129144: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8200
# 2022-05-27 21:08:40.318067: W tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2022-05-27 21:08:40.319333: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.6
# 2022-05-27 21:08:40.319343: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at ptxas
# 2022-05-27 21:08:40.319389: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# Batch: 1000/1000 - loss: 40.5530 - dice_loss: 0.4409 - disc_loss: 38.34833
#                loss_val: 2.2309 - dice_loss_val: 0.3969 - disc_loss_val: 0.2462
# Validation loss decresaed from inf to 2.2309. Models' weights are now saved.
#
# Epoch 2/500
# Batch: 1000/1000 - loss: 3.1522 - dice_loss: 0.3976 - disc_loss: 1.1644
#                loss_val: 8.8230 - dice_loss_val: 0.3969 - disc_loss_val: 6.8385
# Validation loss did not decrease from 2.2309.
#
# Epoch 3/500
# Batch: 1000/1000 - loss: 2.9190 - dice_loss: 0.3975 - disc_loss: 0.9315
#                loss_val: 4.9868 - dice_loss_val: 0.3969 - disc_loss_val: 3.0023
# Validation loss did not decrease from 2.2309.
#
# Epoch 4/500
# Batch: 1000/1000 - loss: 2.6690 - dice_loss: 0.3975 - disc_loss: 0.6815
#                loss_val: 2.1477 - dice_loss_val: 0.3969 - disc_loss_val: 0.1632
# Validation loss decresaed from 2.2309 to 2.1477. Models' weights are now saved.
#
# Epoch 5/500
# Batch: 1000/1000 - loss: 308.2059 - dice_loss: 0.8094 - disc_loss: 304.1591
#                loss_val: 5.4039 - dice_loss_val: 0.9823 - disc_loss_val: 0.4924
# Validation loss did not decrease from 2.1477.
#
# Epoch 6/500
# Batch: 1000/1000 - loss: 6.0053 - dice_loss: 0.9818 - disc_loss: 1.0961
#                loss_val: 5.1730 - dice_loss_val: 0.9809 - disc_loss_val: 0.2684
# Validation loss did not decrease from 2.1477.
#
# Epoch 7/500
# Batch: 1000/1000 - loss: 6.0217 - dice_loss: 0.9799 - disc_loss: 1.1221
#                loss_val: 5.1009 - dice_loss_val: 0.9783 - disc_loss_val: 0.2094
# Validation loss did not decrease from 2.1477.
#
# Epoch 8/500
# Batch: 1000/1000 - loss: 5.9540 - dice_loss: 0.9761 - disc_loss: 1.0734
#                loss_val: 5.5152 - dice_loss_val: 0.9726 - disc_loss_val: 0.6522
# Validation loss did not decrease from 2.1477.
#
# Epoch 9/500
# Batch: 1000/1000 - loss: 5.5389 - dice_loss: 0.9268 - disc_loss: 0.9049
#                loss_val: 2.4654 - dice_loss_val: 0.4049 - disc_loss_val: 0.4408
# Validation loss did not decrease from 2.1477.
#
# Epoch 10/500
# Batch: 1000/1000 - loss: 2.6026 - dice_loss: 0.4000 - disc_loss: 0.6026
#                loss_val: 2.5480 - dice_loss_val: 0.3973 - disc_loss_val: 0.5613
# Validation loss did not decrease from 2.1477.
#
# Epoch 11/500
# Batch: 1000/1000 - loss: 2.6537 - dice_loss: 0.3979 - disc_loss: 0.6641
#                loss_val: 2.6084 - dice_loss_val: 0.3971 - disc_loss_val: 0.6228
# Validation loss did not decrease from 2.1477.
#
# Epoch 12/500
# Batch: 1000/1000 - loss: 89.1826 - dice_loss: 0.4009 - disc_loss: 87.17807
#                loss_val: 2.6728 - dice_loss_val: 0.4002 - disc_loss_val: 0.6717
# Validation loss did not decrease from 2.1477.
#
# Epoch 13/500
# Batch: 1000/1000 - loss: 2.3376 - dice_loss: 0.4001 - disc_loss: 0.3373
#                loss_val: 2.3792 - dice_loss_val: 0.3979 - disc_loss_val: 0.3897
# Validation loss did not decrease from 2.1477.
#
# Epoch 14/500
# Batch: 1000/1000 - loss: 2.3415 - dice_loss: 0.3985 - disc_loss: 0.3491
#                loss_val: 2.1254 - dice_loss_val: 0.3973 - disc_loss_val: 0.1387
# Validation loss decresaed from 2.1477 to 2.1254. Models' weights are now saved.
#
# Epoch 15/500
# Batch: 1000/1000 - loss: 2.3936 - dice_loss: 0.3979 - disc_loss: 0.4039
#                loss_val: 2.1247 - dice_loss_val: 0.3971 - disc_loss_val: 0.1392
# Validation loss decresaed from 2.1254 to 2.1247. Models' weights are now saved.
#
# Epoch 16/500
# Batch: 1000/1000 - loss: 2.4434 - dice_loss: 0.3977 - disc_loss: 0.4547
#                loss_val: 2.0656 - dice_loss_val: 0.3970 - disc_loss_val: 0.0807
# Validation loss decresaed from 2.1247 to 2.0656. Models' weights are now saved.
#
# Epoch 17/500
# Batch: 1000/1000 - loss: 2.4755 - dice_loss: 0.3976 - disc_loss: 0.4875
#                loss_val: 2.0514 - dice_loss_val: 0.3969 - disc_loss_val: 0.0667
# Validation loss decresaed from 2.0656 to 2.0514. Models' weights are now saved.
#
# Epoch 18/500
# Batch: 1000/1000 - loss: 2.5504 - dice_loss: 0.3976 - disc_loss: 0.5626
#                loss_val: 2.0458 - dice_loss_val: 0.3969 - disc_loss_val: 0.0612
# Validation loss decresaed from 2.0514 to 2.0458. Models' weights are now saved.
#
# Epoch 19/500
# Batch: 1000/1000 - loss: 2.6634 - dice_loss: 0.3975 - disc_loss: 0.6758
#                loss_val: 2.0219 - dice_loss_val: 0.3969 - disc_loss_val: 0.0373
# Validation loss decresaed from 2.0458 to 2.0219. Models' weights are now saved.
#
# Epoch 20/500
# Batch: 1000/1000 - loss: 437.8029 - dice_loss: 0.3975 - disc_loss: 435.8154
#                loss_val: 2.1065 - dice_loss_val: 0.3969 - disc_loss_val: 0.1220
# Validation loss did not decrease from 2.0219.
#
# Epoch 21/500
# Batch: 1000/1000 - loss: 2.5608 - dice_loss: 0.3975 - disc_loss: 0.5733
#                loss_val: 2.4446 - dice_loss_val: 0.3969 - disc_loss_val: 0.4601
# Validation loss did not decrease from 2.0219.
#
# Epoch 22/500
# Batch: 1000/1000 - loss: 3.8433 - dice_loss: 0.3975 - disc_loss: 1.8558
#                loss_val: 13.1319 - dice_loss_val: 0.3969 - disc_loss_val: 11.1474
# Validation loss did not decrease from 2.0219.
#
# Epoch 23/500
# Batch: 1000/1000 - loss: 4.1662 - dice_loss: 0.3975 - disc_loss: 2.1787
#                loss_val: 8.7125 - dice_loss_val: 0.3969 - disc_loss_val: 6.7280
# Validation loss did not decrease from 2.0219.
#
# Epoch 24/500
# Batch: 1000/1000 - loss: 3.3300 - dice_loss: 0.3975 - disc_loss: 1.3425
#                loss_val: 7.2470 - dice_loss_val: 0.3969 - disc_loss_val: 5.2625
# Validation loss did not decrease from 2.0219.
#
# Epoch 25/500
# Batch: 1000/1000 - loss: 3.0294 - dice_loss: 0.3975 - disc_loss: 1.0419
#                loss_val: 7.0067 - dice_loss_val: 0.3969 - disc_loss_val: 5.0223
# Validation loss did not decrease from 2.0219.
#
# Epoch 26/500
# Batch: 1000/1000 - loss: 2.7972 - dice_loss: 0.3975 - disc_loss: 0.8097
#                loss_val: 4.0772 - dice_loss_val: 0.3969 - disc_loss_val: 2.0928
# Validation loss did not decrease from 2.0219.
#
# Epoch 27/500
# Batch: 1000/1000 - loss: 803.4618 - dice_loss: 0.3975 - disc_loss: 801.47470
#                loss_val: 3.0557 - dice_loss_val: 0.3969 - disc_loss_val: 1.0713
# Validation loss did not decrease from 2.0219.
#
# Epoch 28/500
# Batch: 1000/1000 - loss: 2.4028 - dice_loss: 0.3983 - disc_loss: 0.4111
#                loss_val: 3.1421 - dice_loss_val: 0.3969 - disc_loss_val: 1.1576
# Validation loss did not decrease from 2.0219.
#
# Epoch 29/500
# Batch: 1000/1000 - loss: 2.4694 - dice_loss: 0.3978 - disc_loss: 0.4806
#                loss_val: 3.0620 - dice_loss_val: 0.3969 - disc_loss_val: 1.0776
# Validation loss did not decrease from 2.0219.
#
# Epoch 30/500
# Batch: 1000/1000 - loss: 2.6675 - dice_loss: 0.3975 - disc_loss: 0.6797
#                loss_val: 3.7986 - dice_loss_val: 0.3969 - disc_loss_val: 1.8141
# Validation loss did not decrease from 2.0219.
#
# Epoch 31/500
# Batch: 1000/1000 - loss: 2.7061 - dice_loss: 0.3975 - disc_loss: 0.7187
#                loss_val: 3.1634 - dice_loss_val: 0.3969 - disc_loss_val: 1.1789
# Validation loss did not decrease from 2.0219.
#
# Epoch 32/500
# Batch: 1000/1000 - loss: 3.0380 - dice_loss: 0.3975 - disc_loss: 1.0506
#                loss_val: 4.3000 - dice_loss_val: 0.3969 - disc_loss_val: 2.3155
# Validation loss did not decrease from 2.0219.
#
# Epoch 33/500
# Batch: 1000/1000 - loss: 3.3611 - dice_loss: 0.3975 - disc_loss: 1.3737
#                loss_val: 4.5587 - dice_loss_val: 0.3969 - disc_loss_val: 2.5742
# Validation loss did not decrease from 2.0219.
#
# Epoch 34/500
# Batch: 1000/1000 - loss: 20.8013 - dice_loss: 0.3975 - disc_loss: 18.8139
#                loss_val: 2.0951 - dice_loss_val: 0.3969 - disc_loss_val: 0.1107
# Validation loss did not decrease from 2.0219.
#
# Epoch 35/500
# Batch: 1000/1000 - loss: 2.4287 - dice_loss: 0.3975 - disc_loss: 0.4412
#                loss_val: 2.1501 - dice_loss_val: 0.3969 - disc_loss_val: 0.1656
# Validation loss did not decrease from 2.0219.
#
# Epoch 36/500
# Batch: 1000/1000 - loss: 2.4777 - dice_loss: 0.3975 - disc_loss: 0.4902
#                loss_val: 2.2805 - dice_loss_val: 0.3969 - disc_loss_val: 0.2961
# Validation loss did not decrease from 2.0219.
#
# Epoch 37/500
# Batch: 1000/1000 - loss: 2.5985 - dice_loss: 0.3975 - disc_loss: 0.6110
#                loss_val: 2.1078 - dice_loss_val: 0.3969 - disc_loss_val: 0.1233
# Validation loss did not decrease from 2.0219.
#
# Epoch 38/500
# Batch: 1000/1000 - loss: 2.7037 - dice_loss: 0.3975 - disc_loss: 0.7163
#                loss_val: 2.0345 - dice_loss_val: 0.3969 - disc_loss_val: 0.0500
# Validation loss did not decrease from 2.0219.
#
# Epoch 39/500
# Batch: 1000/1000 - loss: 2.8005 - dice_loss: 0.3975 - disc_loss: 0.8130
#                loss_val: 2.2513 - dice_loss_val: 0.3969 - disc_loss_val: 0.2668
# Validation loss did not decrease from 2.0219.
#
# Epoch 40/500
# Batch: 1000/1000 - loss: 557.5759 - dice_loss: 0.3983 - disc_loss: 555.5840
#                loss_val: 4.6736 - dice_loss_val: 0.3969 - disc_loss_val: 2.6891
# Validation loss did not decrease from 2.0219.
#
# Epoch 41/500
# Batch: 1000/1000 - loss: 2.8098 - dice_loss: 0.3975 - disc_loss: 0.8223
#                loss_val: 2.6374 - dice_loss_val: 0.3969 - disc_loss_val: 0.6529
# Validation loss did not decrease from 2.0219.
#
# Epoch 42/500
# Batch: 1000/1000 - loss: 2.8291 - dice_loss: 0.3975 - disc_loss: 0.8416
#                loss_val: 4.0856 - dice_loss_val: 0.3969 - disc_loss_val: 2.1011
# Validation loss did not decrease from 2.0219.
#
# Epoch 43/500
# Batch: 1000/1000 - loss: 2.8660 - dice_loss: 0.3975 - disc_loss: 0.8786
#                loss_val: 2.4221 - dice_loss_val: 0.3969 - disc_loss_val: 0.4376
# Validation loss did not decrease from 2.0219.
#
# Epoch 44/500
# Batch: 1000/1000 - loss: 2.7945 - dice_loss: 0.3975 - disc_loss: 0.8071
#                loss_val: 2.8394 - dice_loss_val: 0.3969 - disc_loss_val: 0.8550
# Validation loss did not decrease from 2.0219.
#
# Epoch 45/500
# Batch: 1000/1000 - loss: 2.7732 - dice_loss: 0.3975 - disc_loss: 0.7857
#                loss_val: 2.3297 - dice_loss_val: 0.3969 - disc_loss_val: 0.3453
# Validation loss did not decrease from 2.0219.
#
# Epoch 46/500
# Batch: 1000/1000 - loss: 2.7224 - dice_loss: 0.3975 - disc_loss: 0.7349
#                loss_val: 2.1730 - dice_loss_val: 0.3969 - disc_loss_val: 0.1886
# Validation loss did not decrease from 2.0219.
#
# Epoch 47/500
# Batch: 1000/1000 - loss: 2.7257 - dice_loss: 0.3975 - disc_loss: 0.7383
#                loss_val: 2.1174 - dice_loss_val: 0.3969 - disc_loss_val: 0.1330
# Validation loss did not decrease from 2.0219.
#
# Epoch 48/500
# Batch: 1000/1000 - loss: 2.7584 - dice_loss: 0.3975 - disc_loss: 0.7710
#                loss_val: 2.0948 - dice_loss_val: 0.3969 - disc_loss_val: 0.1103
# Validation loss did not decrease from 2.0219.
#
# Epoch 49/500
# Batch: 1000/1000 - loss: 2.8199 - dice_loss: 0.3975 - disc_loss: 0.8325
#                loss_val: 2.5230 - dice_loss_val: 0.3969 - disc_loss_val: 0.5386
# Validation loss did not decrease from 2.0219.
#
# Epoch 50/500
# Batch: 1000/1000 - loss: 2.9227 - dice_loss: 0.3975 - disc_loss: 0.9352
#                loss_val: 2.8038 - dice_loss_val: 0.3969 - disc_loss_val: 0.8193
# Validation loss did not decrease from 2.0219.
#
# Epoch 51/500
# Batch: 1000/1000 - loss: 211.4243 - dice_loss: 0.3975 - disc_loss: 209.4369
#                loss_val: 3.5152 - dice_loss_val: 0.3969 - disc_loss_val: 1.5308
# Validation loss did not decrease from 2.0219.
#
# Epoch 52/500
# Batch: 1000/1000 - loss: 2.4736 - dice_loss: 0.3975 - disc_loss: 0.4862
#                loss_val: 2.8408 - dice_loss_val: 0.3969 - disc_loss_val: 0.8564
# Validation loss did not decrease from 2.0219.
#
# Epoch 53/500
# Batch: 1000/1000 - loss: 2.4734 - dice_loss: 0.3975 - disc_loss: 0.4860
#                loss_val: 2.5303 - dice_loss_val: 0.3969 - disc_loss_val: 0.5459
# Validation loss did not decrease from 2.0219.
#
# Epoch 54/500
# Batch: 1000/1000 - loss: 2.4950 - dice_loss: 0.3975 - disc_loss: 0.5076
#                loss_val: 2.5077 - dice_loss_val: 0.3969 - disc_loss_val: 0.5232
# Validation loss did not decrease from 2.0219.
#
# Epoch 55/500
# Batch: 1000/1000 - loss: 2.5133 - dice_loss: 0.3975 - disc_loss: 0.5258
#                loss_val: 2.5523 - dice_loss_val: 0.3969 - disc_loss_val: 0.5679
# Validation loss did not decrease from 2.0219.
#
# Epoch 56/500
# Batch: 1000/1000 - loss: 2.5394 - dice_loss: 0.3975 - disc_loss: 0.5520
#                loss_val: 2.6274 - dice_loss_val: 0.3969 - disc_loss_val: 0.6430
# Validation loss did not decrease from 2.0219.
#
# Epoch 57/500
# Batch: 1000/1000 - loss: 2.6150 - dice_loss: 0.3975 - disc_loss: 0.6275
#                loss_val: 2.6635 - dice_loss_val: 0.3969 - disc_loss_val: 0.6790
# Validation loss did not decrease from 2.0219.
#
# Epoch 58/500
# Batch: 1000/1000 - loss: 6116.0850 - dice_loss: 0.3975 - disc_loss: 6114.08798
#                loss_val: 2.5220 - dice_loss_val: 0.3969 - disc_loss_val: 0.5375
# Validation loss did not decrease from 2.0219.
#
# Epoch 59/500
# Batch: 1000/1000 - loss: 2.5155 - dice_loss: 0.3975 - disc_loss: 0.5281
#                loss_val: 2.6661 - dice_loss_val: 0.3969 - disc_loss_val: 0.6816
# Validation loss did not decrease from 2.0219.
#
# Epoch 60/500
# Batch: 1000/1000 - loss: 2.6584 - dice_loss: 0.3975 - disc_loss: 0.6710
#                loss_val: 3.0869 - dice_loss_val: 0.3969 - disc_loss_val: 1.1024
# Validation loss did not decrease from 2.0219.
#
# Epoch 61/500
# Batch: 1000/1000 - loss: 2.6351 - dice_loss: 0.3975 - disc_loss: 0.6477
#                loss_val: 2.8754 - dice_loss_val: 0.3969 - disc_loss_val: 0.8910
# Validation loss did not decrease from 2.0219.
#
# Epoch 62/500
# Batch: 1000/1000 - loss: 118.2240 - dice_loss: 0.3975 - disc_loss: 116.2366
#                loss_val: 2.2755 - dice_loss_val: 0.3969 - disc_loss_val: 0.2910
# Validation loss did not decrease from 2.0219.
#
# Epoch 63/500
# Batch: 1000/1000 - loss: 2.3192 - dice_loss: 0.3975 - disc_loss: 0.3318
#                loss_val: 2.1284 - dice_loss_val: 0.3969 - disc_loss_val: 0.1439
# Validation loss did not decrease from 2.0219.
#
# Epoch 64/500
# Batch: 1000/1000 - loss: 2.3813 - dice_loss: 0.3975 - disc_loss: 0.3939
#                loss_val: 2.1928 - dice_loss_val: 0.3969 - disc_loss_val: 0.2083
# Validation loss did not decrease from 2.0219.
#
# Epoch 65/500
# Batch: 1000/1000 - loss: 2.4623 - dice_loss: 0.3975 - disc_loss: 0.4748
#                loss_val: 2.2457 - dice_loss_val: 0.3969 - disc_loss_val: 0.2612
# Validation loss did not decrease from 2.0219.
#
# Epoch 66/500
# Batch: 1000/1000 - loss: 2.5297 - dice_loss: 0.3975 - disc_loss: 0.5422
#                loss_val: 2.1842 - dice_loss_val: 0.3969 - disc_loss_val: 0.1997
# Validation loss did not decrease from 2.0219.
#
# Epoch 67/500
# Batch: 1000/1000 - loss: 2.6182 - dice_loss: 0.3975 - disc_loss: 0.6307
#                loss_val: 2.0399 - dice_loss_val: 0.3969 - disc_loss_val: 0.0554
# Validation loss did not decrease from 2.0219.
#
# Epoch 68/500
# Batch: 1000/1000 - loss: 2.6759 - dice_loss: 0.3975 - disc_loss: 0.6885
#                loss_val: 2.0576 - dice_loss_val: 0.3969 - disc_loss_val: 0.0731
# Validation loss did not decrease from 2.0219.
#
# Epoch 69/500
# Batch: 1000/1000 - loss: 2.6834 - dice_loss: 0.3975 - disc_loss: 0.6959
#                loss_val: 2.1833 - dice_loss_val: 0.3969 - disc_loss_val: 0.1989
# Validation loss did not decrease from 2.0219.
#
# Epoch 70/500
# Batch: 1000/1000 - loss: 1025.6798 - dice_loss: 0.3975 - disc_loss: 1023.6937
#                loss_val: 2.4245 - dice_loss_val: 0.3969 - disc_loss_val: 0.4401
# Validation loss did not decrease from 2.0219.
#
# Epoch 71/500
# Batch: 1000/1000 - loss: 2.3446 - dice_loss: 0.3975 - disc_loss: 0.3571
#                loss_val: 2.3619 - dice_loss_val: 0.3969 - disc_loss_val: 0.3774
# Validation loss did not decrease from 2.0219.
#
# Epoch 72/500
# Batch: 1000/1000 - loss: 2.3656 - dice_loss: 0.3975 - disc_loss: 0.3782
#                loss_val: 2.2417 - dice_loss_val: 0.3969 - disc_loss_val: 0.2572
# Validation loss did not decrease from 2.0219.
#
# Epoch 73/500
# Batch: 1000/1000 - loss: 2.3946 - dice_loss: 0.3975 - disc_loss: 0.4072
#                loss_val: 2.1560 - dice_loss_val: 0.3969 - disc_loss_val: 0.1716
# Validation loss did not decrease from 2.0219.
#
# Epoch 74/500
# Batch: 1000/1000 - loss: 2.4401 - dice_loss: 0.3975 - disc_loss: 0.4526
#                loss_val: 2.1517 - dice_loss_val: 0.3969 - disc_loss_val: 0.1672
# Validation loss did not decrease from 2.0219.
#
# Epoch 75/500
# Batch: 1000/1000 - loss: 2.4810 - dice_loss: 0.3975 - disc_loss: 0.4935
#                loss_val: 2.1444 - dice_loss_val: 0.3969 - disc_loss_val: 0.1599
# Validation loss did not decrease from 2.0219.
#
# Epoch 76/500
# Batch: 1000/1000 - loss: 2.4984 - dice_loss: 0.3975 - disc_loss: 0.5109
#                loss_val: 2.0813 - dice_loss_val: 0.3969 - disc_loss_val: 0.0968
# Validation loss did not decrease from 2.0219.
#
# Epoch 77/500
# Batch: 1000/1000 - loss: 2.5059 - dice_loss: 0.3975 - disc_loss: 0.5185
#                loss_val: 2.0818 - dice_loss_val: 0.3969 - disc_loss_val: 0.0973
# Validation loss did not decrease from 2.0219.
#
# Epoch 78/500
# Batch: 1000/1000 - loss: 2.6024 - dice_loss: 0.3975 - disc_loss: 0.6149
#                loss_val: 2.0521 - dice_loss_val: 0.3969 - disc_loss_val: 0.0676
# Validation loss did not decrease from 2.0219.
#
# Epoch 79/500
# Batch: 1000/1000 - loss: 2.7525 - dice_loss: 0.3975 - disc_loss: 0.7651
#                loss_val: 2.5615 - dice_loss_val: 0.3969 - disc_loss_val: 0.5770
# Validation loss did not decrease from 2.0219.
#
# Epoch 80/500
# Batch: 1000/1000 - loss: 2.9075 - dice_loss: 0.3975 - disc_loss: 0.9201
#                loss_val: 3.3244 - dice_loss_val: 0.3969 - disc_loss_val: 1.3399
# Validation loss did not decrease from 2.0219.
#
# Epoch 81/500
# Batch: 1000/1000 - loss: 2.9310 - dice_loss: 0.3975 - disc_loss: 0.9436
#                loss_val: 3.5850 - dice_loss_val: 0.3969 - disc_loss_val: 1.6005
# Validation loss did not decrease from 2.0219.
#
# Epoch 82/500
# Batch: 1000/1000 - loss: 2.9870 - dice_loss: 0.3975 - disc_loss: 0.9996
#                loss_val: 3.0558 - dice_loss_val: 0.3969 - disc_loss_val: 1.0714
# Validation loss did not decrease from 2.0219.
#
# Epoch 83/500
# Batch: 1000/1000 - loss: 229.6692 - dice_loss: 0.3975 - disc_loss: 227.6817
#                loss_val: 2.9941 - dice_loss_val: 0.3969 - disc_loss_val: 1.0096
# Validation loss did not decrease from 2.0219.
#
# Epoch 84/500
# Batch: 1000/1000 - loss: 2.5255 - dice_loss: 0.3975 - disc_loss: 0.5380
#                loss_val: 2.3403 - dice_loss_val: 0.3969 - disc_loss_val: 0.3558
# Validation loss did not decrease from 2.0219.
#
# Epoch 85/500
# Batch: 1000/1000 - loss: 2.4659 - dice_loss: 0.3975 - disc_loss: 0.4784
#                loss_val: 2.1852 - dice_loss_val: 0.3969 - disc_loss_val: 0.2008
# Validation loss did not decrease from 2.0219.
#
# Epoch 86/500
# Batch: 1000/1000 - loss: 2.4568 - dice_loss: 0.3975 - disc_loss: 0.4694
#                loss_val: 2.1896 - dice_loss_val: 0.3969 - disc_loss_val: 0.2051
# Validation loss did not decrease from 2.0219.
#
# Epoch 87/500
# Batch: 1000/1000 - loss: 2.4373 - dice_loss: 0.3975 - disc_loss: 0.4498
#                loss_val: 2.2479 - dice_loss_val: 0.3969 - disc_loss_val: 0.2635
# Validation loss did not decrease from 2.0219.
#
# Epoch 88/500
# Batch: 1000/1000 - loss: 2.4262 - dice_loss: 0.3975 - disc_loss: 0.4388
#                loss_val: 2.2339 - dice_loss_val: 0.3969 - disc_loss_val: 0.2495
# Validation loss did not decrease from 2.0219.
#
# Epoch 89/500
# Batch: 1000/1000 - loss: 2.4376 - dice_loss: 0.3975 - disc_loss: 0.4502
#                loss_val: 2.1862 - dice_loss_val: 0.3969 - disc_loss_val: 0.2018
# Validation loss did not decrease from 2.0219.
#
# Epoch 90/500
# Batch: 1000/1000 - loss: 2.4725 - dice_loss: 0.3975 - disc_loss: 0.4851
#                loss_val: 2.0656 - dice_loss_val: 0.3969 - disc_loss_val: 0.0811
# Validation loss did not decrease from 2.0219.
#
# Epoch 91/500
# Batch: 1000/1000 - loss: 2.5455 - dice_loss: 0.3975 - disc_loss: 0.5581
#                loss_val: 2.0288 - dice_loss_val: 0.3969 - disc_loss_val: 0.0444
# Validation loss did not decrease from 2.0219.
#
# Epoch 92/500
# Batch: 1000/1000 - loss: 2.6112 - dice_loss: 0.3975 - disc_loss: 0.6238
#                loss_val: 2.0423 - dice_loss_val: 0.3969 - disc_loss_val: 0.0578
# Validation loss did not decrease from 2.0219.
#
# Epoch 93/500
# Batch: 1000/1000 - loss: 2.6745 - dice_loss: 0.3975 - disc_loss: 0.6871
#                loss_val: 2.1520 - dice_loss_val: 0.3969 - disc_loss_val: 0.1675
# Validation loss did not decrease from 2.0219.
#
# Epoch 94/500
# Batch: 1000/1000 - loss: 99.6571 - dice_loss: 0.3975 - disc_loss: 97.66961
#                loss_val: 2.1254 - dice_loss_val: 0.3969 - disc_loss_val: 0.1409
# Validation loss did not decrease from 2.0219.
#
# Epoch 95/500
# Batch: 1000/1000 - loss: 2.6466 - dice_loss: 0.3975 - disc_loss: 0.6592
#                loss_val: 2.2636 - dice_loss_val: 0.3969 - disc_loss_val: 0.2792
# Validation loss did not decrease from 2.0219.
#
# Epoch 96/500
# Batch: 1000/1000 - loss: 2.7988 - dice_loss: 0.3975 - disc_loss: 0.8114
#                loss_val: 2.2426 - dice_loss_val: 0.3969 - disc_loss_val: 0.2582
# Validation loss did not decrease from 2.0219.
#
# Epoch 97/500
# Batch: 1000/1000 - loss: 2.7856 - dice_loss: 0.3975 - disc_loss: 0.7981
#                loss_val: 2.0161 - dice_loss_val: 0.3969 - disc_loss_val: 0.0316
# Validation loss decresaed from 2.0219 to 2.0161. Models' weights are now saved.
#
# Epoch 98/500
# Batch: 1000/1000 - loss: 2.7359 - dice_loss: 0.3975 - disc_loss: 0.7484
#                loss_val: 2.2225 - dice_loss_val: 0.3969 - disc_loss_val: 0.2381
# Validation loss did not decrease from 2.0161.
#
# Epoch 99/500
# Batch: 1000/1000 - loss: 2.7153 - dice_loss: 0.3975 - disc_loss: 0.7278
#                loss_val: 2.5213 - dice_loss_val: 0.3969 - disc_loss_val: 0.5369
# Validation loss did not decrease from 2.0161.
#
# Epoch 100/500
# Batch: 1000/1000 - loss: 2.7269 - dice_loss: 0.3975 - disc_loss: 0.7395
#                loss_val: 2.6585 - dice_loss_val: 0.3969 - disc_loss_val: 0.6740
# Validation loss did not decrease from 2.0161.
#
# Epoch 101/500
# Batch: 1000/1000 - loss: 1660.1395 - dice_loss: 0.3975 - disc_loss: 1658.1517
#                loss_val: 3.1472 - dice_loss_val: 0.3969 - disc_loss_val: 1.1627
# Validation loss did not decrease from 2.0161.
#
# Epoch 102/500
# Batch: 1000/1000 - loss: 2.7255 - dice_loss: 0.3975 - disc_loss: 0.7381
#                loss_val: 2.9376 - dice_loss_val: 0.3969 - disc_loss_val: 0.9531
# Validation loss did not decrease from 2.0161.
#
# Epoch 103/500
# Batch: 1000/1000 - loss: 2.6818 - dice_loss: 0.3975 - disc_loss: 0.6943
#                loss_val: 2.6470 - dice_loss_val: 0.3969 - disc_loss_val: 0.6625
# Validation loss did not decrease from 2.0161.
#
# Epoch 104/500
# Batch: 1000/1000 - loss: 2.6900 - dice_loss: 0.3975 - disc_loss: 0.7026
#                loss_val: 2.4857 - dice_loss_val: 0.3969 - disc_loss_val: 0.5013
# Validation loss did not decrease from 2.0161.
#
# Epoch 105/500
# Batch: 1000/1000 - loss: 2.7422 - dice_loss: 0.3975 - disc_loss: 0.7547
#                loss_val: 2.3604 - dice_loss_val: 0.3969 - disc_loss_val: 0.3760
# Validation loss did not decrease from 2.0161.
#
# Epoch 106/500
# Batch: 1000/1000 - loss: 2.8217 - dice_loss: 0.3975 - disc_loss: 0.8342
#                loss_val: 2.3509 - dice_loss_val: 0.3969 - disc_loss_val: 0.3665
# Validation loss did not decrease from 2.0161.
#
# Epoch 107/500
# Batch: 1000/1000 - loss: 2.7457 - dice_loss: 0.3975 - disc_loss: 0.7582
#                loss_val: 2.4098 - dice_loss_val: 0.3969 - disc_loss_val: 0.4253
# Validation loss did not decrease from 2.0161.
#
# Epoch 108/500
# Batch: 1000/1000 - loss: 2.7105 - dice_loss: 0.3975 - disc_loss: 0.7230
#                loss_val: 2.5342 - dice_loss_val: 0.3969 - disc_loss_val: 0.5498
# Validation loss did not decrease from 2.0161.
#
# Epoch 109/500
# Batch: 1000/1000 - loss: 2.6606 - dice_loss: 0.3975 - disc_loss: 0.6732
#                loss_val: 2.4948 - dice_loss_val: 0.3969 - disc_loss_val: 0.5104
# Validation loss did not decrease from 2.0161.
#
# Epoch 110/500
# Batch: 1000/1000 - loss: 2.6664 - dice_loss: 0.3975 - disc_loss: 0.6790
#                loss_val: 2.5733 - dice_loss_val: 0.3969 - disc_loss_val: 0.5888
# Validation loss did not decrease from 2.0161.
#
# Epoch 111/500
# Batch: 1000/1000 - loss: 1052.6266 - dice_loss: 0.3975 - disc_loss: 1050.6390
#                loss_val: 36.1362 - dice_loss_val: 0.3969 - disc_loss_val: 34.1517
# Validation loss did not decrease from 2.0161.
#
# Epoch 112/500
# Batch: 1000/1000 - loss: 4.7359 - dice_loss: 0.3975 - disc_loss: 2.74850
#                loss_val: 3.9432 - dice_loss_val: 0.3969 - disc_loss_val: 1.9587
# Validation loss did not decrease from 2.0161.
#
# Epoch 113/500
# Batch: 1000/1000 - loss: 2.8865 - dice_loss: 0.3975 - disc_loss: 0.8990
#                loss_val: 4.1695 - dice_loss_val: 0.3969 - disc_loss_val: 2.1850
# Validation loss did not decrease from 2.0161.
#
# Epoch 114/500
# Batch: 1000/1000 - loss: 2.6744 - dice_loss: 0.3975 - disc_loss: 0.6869
#                loss_val: 2.7431 - dice_loss_val: 0.3969 - disc_loss_val: 0.7586
# Validation loss did not decrease from 2.0161.
#
# Epoch 115/500
# Batch: 1000/1000 - loss: 2.6476 - dice_loss: 0.3975 - disc_loss: 0.6601
#                loss_val: 2.6906 - dice_loss_val: 0.3969 - disc_loss_val: 0.7061
# Validation loss did not decrease from 2.0161.
#
# Epoch 116/500
# Batch: 1000/1000 - loss: 2.6561 - dice_loss: 0.3975 - disc_loss: 0.6686
#                loss_val: 2.7605 - dice_loss_val: 0.3969 - disc_loss_val: 0.7761
# Validation loss did not decrease from 2.0161.
#
# Epoch 117/500
# Batch: 1000/1000 - loss: 2.6367 - dice_loss: 0.3975 - disc_loss: 0.6492
#                loss_val: 2.4021 - dice_loss_val: 0.3969 - disc_loss_val: 0.4176
# Validation loss did not decrease from 2.0161.
#
# Epoch 118/500
# Batch: 1000/1000 - loss: 2.6224 - dice_loss: 0.3975 - disc_loss: 0.6349
#                loss_val: 2.1066 - dice_loss_val: 0.3969 - disc_loss_val: 0.1221
# Validation loss did not decrease from 2.0161.
#
# Epoch 119/500
# Batch: 1000/1000 - loss: 2.6316 - dice_loss: 0.3975 - disc_loss: 0.6442
#                loss_val: 2.0506 - dice_loss_val: 0.3969 - disc_loss_val: 0.0661
# Validation loss did not decrease from 2.0161.
#
# Epoch 120/500
# Batch: 1000/1000 - loss: 2.6938 - dice_loss: 0.3975 - disc_loss: 0.7063
#                loss_val: 2.0431 - dice_loss_val: 0.3969 - disc_loss_val: 0.0586
# Validation loss did not decrease from 2.0161.
#
# Epoch 121/500
# Batch: 1000/1000 - loss: 98.3167 - dice_loss: 0.3975 - disc_loss: 96.32923
#                loss_val: 2.3492 - dice_loss_val: 0.3969 - disc_loss_val: 0.3647
# Validation loss did not decrease from 2.0161.
#
# Epoch 122/500
# Batch: 1000/1000 - loss: 2.4091 - dice_loss: 0.3975 - disc_loss: 0.4216
#                loss_val: 2.2633 - dice_loss_val: 0.3969 - disc_loss_val: 0.2789
# Validation loss did not decrease from 2.0161.
#
# Epoch 123/500
# Batch: 1000/1000 - loss: 2.7635 - dice_loss: 0.3975 - disc_loss: 0.7761
#                loss_val: 2.1065 - dice_loss_val: 0.3969 - disc_loss_val: 0.1220
# Validation loss did not decrease from 2.0161.
#
# Epoch 124/500
# Batch: 1000/1000 - loss: 2.6420 - dice_loss: 0.3975 - disc_loss: 0.6546
#                loss_val: 2.2466 - dice_loss_val: 0.3969 - disc_loss_val: 0.2621
# Validation loss did not decrease from 2.0161.
#
# Epoch 125/500
# Batch: 1000/1000 - loss: 2.5030 - dice_loss: 0.3975 - disc_loss: 0.5155
#                loss_val: 2.0813 - dice_loss_val: 0.3969 - disc_loss_val: 0.0968
# Validation loss did not decrease from 2.0161.
#
# Epoch 126/500
# Batch: 1000/1000 - loss: 2.4874 - dice_loss: 0.3975 - disc_loss: 0.5000
#                loss_val: 2.1122 - dice_loss_val: 0.3969 - disc_loss_val: 0.1277
# Validation loss did not decrease from 2.0161.
#
# Epoch 127/500
# Batch: 1000/1000 - loss: 2.5094 - dice_loss: 0.3975 - disc_loss: 0.5220
#                loss_val: 2.0475 - dice_loss_val: 0.3969 - disc_loss_val: 0.0630
# Validation loss did not decrease from 2.0161.
#
# Epoch 128/500
# Batch: 1000/1000 - loss: 2.5287 - dice_loss: 0.3975 - disc_loss: 0.5412
#                loss_val: 2.0494 - dice_loss_val: 0.3969 - disc_loss_val: 0.0650
# Validation loss did not decrease from 2.0161.
#
# Epoch 129/500
# Batch: 1000/1000 - loss: 2.5699 - dice_loss: 0.3975 - disc_loss: 0.5825
#                loss_val: 2.0487 - dice_loss_val: 0.3969 - disc_loss_val: 0.0642
# Validation loss did not decrease from 2.0161.
#
# Epoch 130/500
# Batch: 1000/1000 - loss: 2.6400 - dice_loss: 0.3975 - disc_loss: 0.6525
#                loss_val: 2.0685 - dice_loss_val: 0.3969 - disc_loss_val: 0.0841
# Validation loss did not decrease from 2.0161.
#
# Epoch 131/500
# Batch: 1000/1000 - loss: 3578.4304 - dice_loss: 0.3975 - disc_loss: 3576.4431
#                loss_val: 2.0762 - dice_loss_val: 0.3969 - disc_loss_val: 0.0917
# Validation loss did not decrease from 2.0161.
#
# Epoch 132/500
# Batch: 1000/1000 - loss: 2.5065 - dice_loss: 0.3975 - disc_loss: 0.5191
#                loss_val: 2.0237 - dice_loss_val: 0.3969 - disc_loss_val: 0.0393
# Validation loss did not decrease from 2.0161.
#
# Epoch 133/500
# Batch: 1000/1000 - loss: 2.6320 - dice_loss: 0.3975 - disc_loss: 0.6446
#                loss_val: 2.0237 - dice_loss_val: 0.3969 - disc_loss_val: 0.0393
# Validation loss did not decrease from 2.0161.
#
# Epoch 134/500
# Batch: 1000/1000 - loss: 2.7131 - dice_loss: 0.3975 - disc_loss: 0.7257
#                loss_val: 2.0247 - dice_loss_val: 0.3969 - disc_loss_val: 0.0402
# Validation loss did not decrease from 2.0161.
#
# Epoch 135/500
# Batch: 1000/1000 - loss: 2.6755 - dice_loss: 0.3975 - disc_loss: 0.6881
#                loss_val: 2.0190 - dice_loss_val: 0.3969 - disc_loss_val: 0.0346
# Validation loss did not decrease from 2.0161.
#
# Epoch 136/500
# Batch: 1000/1000 - loss: 2.6411 - dice_loss: 0.3975 - disc_loss: 0.6537
#                loss_val: 2.0125 - dice_loss_val: 0.3969 - disc_loss_val: 0.0280
# Validation loss decresaed from 2.0161 to 2.0125. Models' weights are now saved.
#
# Epoch 137/500
# Batch: 1000/1000 - loss: 2.6367 - dice_loss: 0.3975 - disc_loss: 0.6493
#                loss_val: 2.0527 - dice_loss_val: 0.3969 - disc_loss_val: 0.0683
# Validation loss did not decrease from 2.0125.
#
# Epoch 138/500
# Batch: 1000/1000 - loss: 2.6663 - dice_loss: 0.3975 - disc_loss: 0.6789
#                loss_val: 2.0205 - dice_loss_val: 0.3969 - disc_loss_val: 0.0361
# Validation loss did not decrease from 2.0125.
#
# Epoch 139/500
# Batch: 1000/1000 - loss: 2.6935 - dice_loss: 0.3975 - disc_loss: 0.7061
#                loss_val: 2.0200 - dice_loss_val: 0.3969 - disc_loss_val: 0.0355
# Validation loss did not decrease from 2.0125.
#
# Epoch 140/500
# Batch: 1000/1000 - loss: 2.7418 - dice_loss: 0.3975 - disc_loss: 0.7544
#                loss_val: 2.0181 - dice_loss_val: 0.3969 - disc_loss_val: 0.0337
# Validation loss did not decrease from 2.0125.
#
# Epoch 141/500
# Batch: 1000/1000 - loss: 2.7894 - dice_loss: 0.3975 - disc_loss: 0.8020
#                loss_val: 2.0171 - dice_loss_val: 0.3969 - disc_loss_val: 0.0327
# Validation loss did not decrease from 2.0125.
#
# Epoch 142/500
# Batch: 1000/1000 - loss: 2.7938 - dice_loss: 0.3975 - disc_loss: 0.8063
#                loss_val: 2.0670 - dice_loss_val: 0.3969 - disc_loss_val: 0.0826
# Validation loss did not decrease from 2.0125.
#
# Epoch 143/500
# Batch: 1000/1000 - loss: 2814.9980 - dice_loss: 0.3975 - disc_loss: 2813.01256
#                loss_val: 2.0314 - dice_loss_val: 0.3969 - disc_loss_val: 0.0470
# Validation loss did not decrease from 2.0125.
#
# Epoch 144/500
# Batch: 1000/1000 - loss: 2.4147 - dice_loss: 0.3975 - disc_loss: 0.4272
#                loss_val: 2.1045 - dice_loss_val: 0.3969 - disc_loss_val: 0.1201
# Validation loss did not decrease from 2.0125.
#
# Epoch 145/500
# Batch: 1000/1000 - loss: 2.4644 - dice_loss: 0.3975 - disc_loss: 0.4770
#                loss_val: 2.0197 - dice_loss_val: 0.3969 - disc_loss_val: 0.0352
# Validation loss did not decrease from 2.0125.
#
# Epoch 146/500
# Batch: 1000/1000 - loss: 2.5646 - dice_loss: 0.3975 - disc_loss: 0.5772
#                loss_val: 2.0687 - dice_loss_val: 0.3969 - disc_loss_val: 0.0842
# Validation loss did not decrease from 2.0125.
#
# Epoch 147/500
# Batch: 1000/1000 - loss: 2.6131 - dice_loss: 0.3975 - disc_loss: 0.6256
#                loss_val: 2.0588 - dice_loss_val: 0.3969 - disc_loss_val: 0.0744
# Validation loss did not decrease from 2.0125.
#
# Epoch 148/500
# Batch: 1000/1000 - loss: 2.5953 - dice_loss: 0.3975 - disc_loss: 0.6079
#                loss_val: 2.0475 - dice_loss_val: 0.3969 - disc_loss_val: 0.0630
# Validation loss did not decrease from 2.0125.
#
# Epoch 149/500
# Batch: 1000/1000 - loss: 2.5974 - dice_loss: 0.3975 - disc_loss: 0.6099
#                loss_val: 2.0195 - dice_loss_val: 0.3969 - disc_loss_val: 0.0350
# Validation loss did not decrease from 2.0125.
#
# Epoch 150/500
# Batch: 1000/1000 - loss: 2.6671 - dice_loss: 0.3975 - disc_loss: 0.6797
#                loss_val: 2.1638 - dice_loss_val: 0.3969 - disc_loss_val: 0.1794
# Validation loss did not decrease from 2.0125.
#
# Epoch 151/500
# Batch: 1000/1000 - loss: 2.7876 - dice_loss: 0.3975 - disc_loss: 0.8002
#                loss_val: 2.3257 - dice_loss_val: 0.3969 - disc_loss_val: 0.3412
# Validation loss did not decrease from 2.0125.
#
# Epoch 152/500
# Batch: 1000/1000 - loss: 142.9125 - dice_loss: 0.3975 - disc_loss: 140.9252
#                loss_val: 2.0369 - dice_loss_val: 0.3969 - disc_loss_val: 0.0525
# Validation loss did not decrease from 2.0125.
#
# Epoch 153/500
# Batch: 1000/1000 - loss: 4.0530 - dice_loss: 0.3975 - disc_loss: 2.0655
#                loss_val: 2.2038 - dice_loss_val: 0.3969 - disc_loss_val: 0.2194
# Validation loss did not decrease from 2.0125.
#
# Epoch 154/500
# Batch: 1000/1000 - loss: 3.4513 - dice_loss: 0.3975 - disc_loss: 1.4639
#                loss_val: 2.8783 - dice_loss_val: 0.3969 - disc_loss_val: 0.8938
# Validation loss did not decrease from 2.0125.
#
# Epoch 155/500
# Batch: 1000/1000 - loss: 3.3186 - dice_loss: 0.3975 - disc_loss: 1.3312
#                loss_val: 2.6344 - dice_loss_val: 0.3969 - disc_loss_val: 0.6499
# Validation loss did not decrease from 2.0125.
#
# Epoch 156/500
# Batch: 1000/1000 - loss: 3.2749 - dice_loss: 0.3975 - disc_loss: 1.2875
#                loss_val: 5.2181 - dice_loss_val: 0.3969 - disc_loss_val: 3.2336
# Validation loss did not decrease from 2.0125.
#
# Epoch 157/500
# Batch: 1000/1000 - loss: 18.5630 - dice_loss: 0.3975 - disc_loss: 16.5756
#                loss_val: 2.1669 - dice_loss_val: 0.3969 - disc_loss_val: 0.1824
# Validation loss did not decrease from 2.0125.
#
# Epoch 158/500
# Batch: 1000/1000 - loss: 2.2891 - dice_loss: 0.3975 - disc_loss: 0.3016
#                loss_val: 2.1654 - dice_loss_val: 0.3969 - disc_loss_val: 0.1809
# Validation loss did not decrease from 2.0125.
#
# Epoch 159/500
# Batch: 1000/1000 - loss: 2.3583 - dice_loss: 0.3975 - disc_loss: 0.3708
#                loss_val: 2.2527 - dice_loss_val: 0.3969 - disc_loss_val: 0.2682
# Validation loss did not decrease from 2.0125.
#
# Epoch 160/500
# Batch: 1000/1000 - loss: 2.4027 - dice_loss: 0.3975 - disc_loss: 0.4152
#                loss_val: 2.2336 - dice_loss_val: 0.3969 - disc_loss_val: 0.2492
# Validation loss did not decrease from 2.0125.
#
# Epoch 161/500
# Batch: 1000/1000 - loss: 2.4831 - dice_loss: 0.3975 - disc_loss: 0.4957
#                loss_val: 2.1450 - dice_loss_val: 0.3969 - disc_loss_val: 0.1605
# Validation loss did not decrease from 2.0125.
#
# Epoch 162/500
# Batch: 1000/1000 - loss: 2.5840 - dice_loss: 0.3975 - disc_loss: 0.5965
#                loss_val: 2.1133 - dice_loss_val: 0.3969 - disc_loss_val: 0.1288
# Validation loss did not decrease from 2.0125.
#
# Epoch 163/500
# Batch: 1000/1000 - loss: 2.6695 - dice_loss: 0.3975 - disc_loss: 0.6821
#                loss_val: 2.0374 - dice_loss_val: 0.3969 - disc_loss_val: 0.0530
# Validation loss did not decrease from 2.0125.
#
# Epoch 164/500
# Batch: 1000/1000 - loss: 64.5989 - dice_loss: 0.3975 - disc_loss: 62.61142
#                loss_val: 2.3115 - dice_loss_val: 0.3969 - disc_loss_val: 0.3271
# Validation loss did not decrease from 2.0125.
#
# Epoch 165/500
# Batch: 1000/1000 - loss: 2.4570 - dice_loss: 0.3975 - disc_loss: 0.4695
#                loss_val: 2.4189 - dice_loss_val: 0.3969 - disc_loss_val: 0.4345
# Validation loss did not decrease from 2.0125.
#
# Epoch 166/500
# Batch: 1000/1000 - loss: 2.6844 - dice_loss: 0.3975 - disc_loss: 0.6970
#                loss_val: 2.9106 - dice_loss_val: 0.3969 - disc_loss_val: 0.9261
# Validation loss did not decrease from 2.0125.
#
# Epoch 167/500
# Batch: 1000/1000 - loss: 2.8806 - dice_loss: 0.3975 - disc_loss: 0.8932
#                loss_val: 2.6877 - dice_loss_val: 0.3969 - disc_loss_val: 0.7033
# Validation loss did not decrease from 2.0125.
#
# Epoch 168/500
# Batch: 1000/1000 - loss: 2.9011 - dice_loss: 0.3975 - disc_loss: 0.9137
#                loss_val: 2.1965 - dice_loss_val: 0.3969 - disc_loss_val: 0.2120
# Validation loss did not decrease from 2.0125.
#
# Epoch 169/500
# Batch: 1000/1000 - loss: 2.8379 - dice_loss: 0.3975 - disc_loss: 0.8504
#                loss_val: 2.1119 - dice_loss_val: 0.3969 - disc_loss_val: 0.1275
# Validation loss did not decrease from 2.0125.
#
# Epoch 170/500
# Batch: 1000/1000 - loss: 2.7472 - dice_loss: 0.3975 - disc_loss: 0.7598
#                loss_val: 2.2780 - dice_loss_val: 0.3969 - disc_loss_val: 0.2936
# Validation loss did not decrease from 2.0125.
#
# Epoch 171/500
# Batch: 1000/1000 - loss: 1556.6149 - dice_loss: 0.3975 - disc_loss: 1554.6256
#                loss_val: 5.2564 - dice_loss_val: 0.3969 - disc_loss_val: 3.2720
# Validation loss did not decrease from 2.0125.
#
# Epoch 172/500
# Batch: 1000/1000 - loss: 3.5625 - dice_loss: 0.3975 - disc_loss: 1.5751
#                loss_val: 4.8598 - dice_loss_val: 0.3969 - disc_loss_val: 2.8754
# Validation loss did not decrease from 2.0125.
#
# Epoch 173/500
# Batch: 1000/1000 - loss: 3.4305 - dice_loss: 0.3975 - disc_loss: 1.4431
#                loss_val: 6.1989 - dice_loss_val: 0.3969 - disc_loss_val: 4.2144
# Validation loss did not decrease from 2.0125.
#
# Epoch 174/500
# Batch: 1000/1000 - loss: 3.2124 - dice_loss: 0.3975 - disc_loss: 1.2250
#                loss_val: 4.2089 - dice_loss_val: 0.3969 - disc_loss_val: 2.2244
# Validation loss did not decrease from 2.0125.
#
# Epoch 175/500
# Batch: 1000/1000 - loss: 2.9819 - dice_loss: 0.3975 - disc_loss: 0.9945
#                loss_val: 2.2847 - dice_loss_val: 0.3969 - disc_loss_val: 0.3003
# Validation loss did not decrease from 2.0125.
#
# Epoch 176/500
# Batch: 1000/1000 - loss: 2.8161 - dice_loss: 0.3975 - disc_loss: 0.8286
#                loss_val: 2.1735 - dice_loss_val: 0.3969 - disc_loss_val: 0.1890
# Validation loss did not decrease from 2.0125.
#
# Epoch 177/500
# Batch: 1000/1000 - loss: 2.8015 - dice_loss: 0.3975 - disc_loss: 0.8141
#                loss_val: 2.7159 - dice_loss_val: 0.3969 - disc_loss_val: 0.7315
# Validation loss did not decrease from 2.0125.
#
# Epoch 178/500
# Batch: 1000/1000 - loss: 3515.1023 - dice_loss: 0.3975 - disc_loss: 3513.1138
#                loss_val: 2.1382 - dice_loss_val: 0.3969 - disc_loss_val: 0.1537
# Validation loss did not decrease from 2.0125.
#
# Epoch 179/500
# Batch: 1000/1000 - loss: 2.3815 - dice_loss: 0.3975 - disc_loss: 0.3940
#                loss_val: 2.3233 - dice_loss_val: 0.3969 - disc_loss_val: 0.3389
# Validation loss did not decrease from 2.0125.
#
# Epoch 180/500
# Batch: 1000/1000 - loss: 3.0191 - dice_loss: 0.3975 - disc_loss: 1.0317
#                loss_val: 2.3391 - dice_loss_val: 0.3969 - disc_loss_val: 0.3546
# Validation loss did not decrease from 2.0125.
#
# Epoch 181/500
# Batch: 1000/1000 - loss: 3.1016 - dice_loss: 0.3975 - disc_loss: 1.1142
#                loss_val: 2.0216 - dice_loss_val: 0.3969 - disc_loss_val: 0.0372
# Validation loss did not decrease from 2.0125.
#
# Epoch 182/500
# Batch: 1000/1000 - loss: 2.7786 - dice_loss: 0.3975 - disc_loss: 0.7911
#                loss_val: 2.2513 - dice_loss_val: 0.3969 - disc_loss_val: 0.2668
# Validation loss did not decrease from 2.0125.
#
# Epoch 183/500
# Batch: 1000/1000 - loss: 2.6320 - dice_loss: 0.3975 - disc_loss: 0.6446
#                loss_val: 2.0448 - dice_loss_val: 0.3969 - disc_loss_val: 0.0604
# Validation loss did not decrease from 2.0125.
#
# Epoch 184/500
# Batch: 1000/1000 - loss: 2.6003 - dice_loss: 0.3975 - disc_loss: 0.6129
#                loss_val: 2.0319 - dice_loss_val: 0.3969 - disc_loss_val: 0.0475
# Validation loss did not decrease from 2.0125.
#
# Epoch 185/500
# Batch: 1000/1000 - loss: 3.5205 - dice_loss: 0.3975 - disc_loss: 1.5331
#                loss_val: 2.0214 - dice_loss_val: 0.3969 - disc_loss_val: 0.0369
# Validation loss did not decrease from 2.0125.
#
# Epoch 186/500
# Batch: 1000/1000 - loss: 3.7628 - dice_loss: 0.3975 - disc_loss: 1.7753
#                loss_val: 6.3685 - dice_loss_val: 0.3969 - disc_loss_val: 4.3840
# Validation loss did not decrease from 2.0125.
#
# Epoch 187/500
# Batch: 1000/1000 - loss: 3.5073 - dice_loss: 0.3975 - disc_loss: 1.5199
#                loss_val: 2.7816 - dice_loss_val: 0.3969 - disc_loss_val: 0.7971
# Validation loss did not decrease from 2.0125.
#
# Epoch 188/500
# Batch: 1000/1000 - loss: 2.9711 - dice_loss: 0.3975 - disc_loss: 0.9837
#                loss_val: 2.4799 - dice_loss_val: 0.3969 - disc_loss_val: 0.4955
# Validation loss did not decrease from 2.0125.
#
# Epoch 189/500
# Batch: 1000/1000 - loss: 3.0013 - dice_loss: 0.3975 - disc_loss: 1.0138
#                loss_val: 2.1593 - dice_loss_val: 0.3969 - disc_loss_val: 0.1748
# Validation loss did not decrease from 2.0125.
#
# Epoch 190/500
# Batch: 1000/1000 - loss: 537.3505 - dice_loss: 0.3975 - disc_loss: 535.36305
#                loss_val: 3.6925 - dice_loss_val: 0.3969 - disc_loss_val: 1.7081
# Validation loss did not decrease from 2.0125.
#
# Epoch 191/500
# Batch: 1000/1000 - loss: 2.5472 - dice_loss: 0.3975 - disc_loss: 0.5598
#                loss_val: 2.8219 - dice_loss_val: 0.3969 - disc_loss_val: 0.8375
# Validation loss did not decrease from 2.0125.
#
# Epoch 192/500
# Batch: 1000/1000 - loss: 2.8121 - dice_loss: 0.3975 - disc_loss: 0.8247
#                loss_val: 4.3608 - dice_loss_val: 0.3969 - disc_loss_val: 2.3763
# Validation loss did not decrease from 2.0125.
#
# Epoch 193/500
# Batch: 1000/1000 - loss: 3.3598 - dice_loss: 0.3975 - disc_loss: 1.3723
#                loss_val: 3.2570 - dice_loss_val: 0.3969 - disc_loss_val: 1.2725
# Validation loss did not decrease from 2.0125.
#
# Epoch 194/500
# Batch: 1000/1000 - loss: 3.1848 - dice_loss: 0.3975 - disc_loss: 1.1973
#                loss_val: 4.6940 - dice_loss_val: 0.3969 - disc_loss_val: 2.7096
# Validation loss did not decrease from 2.0125.
#
# Epoch 195/500
# Batch: 1000/1000 - loss: 2.8952 - dice_loss: 0.3975 - disc_loss: 0.9077
#                loss_val: 3.0589 - dice_loss_val: 0.3969 - disc_loss_val: 1.0745
# Validation loss did not decrease from 2.0125.
#
# Epoch 196/500
# Batch: 1000/1000 - loss: 2.7514 - dice_loss: 0.3975 - disc_loss: 0.7640
#                loss_val: 2.1303 - dice_loss_val: 0.3969 - disc_loss_val: 0.1459
# Validation loss did not decrease from 2.0125.
#
# Epoch 197/500
# Batch: 1000/1000 - loss: 2.6597 - dice_loss: 0.3975 - disc_loss: 0.6722
#                loss_val: 2.0062 - dice_loss_val: 0.3969 - disc_loss_val: 0.0217
# Validation loss decresaed from 2.0125 to 2.0062. Models' weights are now saved.
#
# Epoch 198/500
# Batch: 1000/1000 - loss: 2.6328 - dice_loss: 0.3975 - disc_loss: 0.6454
#                loss_val: 2.1499 - dice_loss_val: 0.3969 - disc_loss_val: 0.1654
# Validation loss did not decrease from 2.0062.
#
# Epoch 199/500
# Batch: 1000/1000 - loss: 2.6644 - dice_loss: 0.3975 - disc_loss: 0.6770
#                loss_val: 2.3404 - dice_loss_val: 0.3969 - disc_loss_val: 0.3559
# Validation loss did not decrease from 2.0062.
#
# Epoch 200/500
# Batch: 1000/1000 - loss: 2.7138 - dice_loss: 0.3975 - disc_loss: 0.7263
#                loss_val: 2.4459 - dice_loss_val: 0.3969 - disc_loss_val: 0.4615
# Validation loss did not decrease from 2.0062.
#
# Epoch 201/500
# Batch: 1000/1000 - loss: 1862.1479 - dice_loss: 0.3975 - disc_loss: 1860.1617
#                loss_val: 2.2706 - dice_loss_val: 0.3969 - disc_loss_val: 0.2862
# Validation loss did not decrease from 2.0062.
#
# Epoch 202/500
# Batch: 1000/1000 - loss: 2.3286 - dice_loss: 0.3975 - disc_loss: 0.3411
#                loss_val: 2.2219 - dice_loss_val: 0.3969 - disc_loss_val: 0.2374
# Validation loss did not decrease from 2.0062.
#
# Epoch 203/500
# Batch: 1000/1000 - loss: 2.3291 - dice_loss: 0.3975 - disc_loss: 0.3417
#                loss_val: 2.1739 - dice_loss_val: 0.3969 - disc_loss_val: 0.1895
# Validation loss did not decrease from 2.0062.
#
# Epoch 204/500
# Batch: 1000/1000 - loss: 2.3275 - dice_loss: 0.3975 - disc_loss: 0.3401
#                loss_val: 2.2344 - dice_loss_val: 0.3969 - disc_loss_val: 0.2499
# Validation loss did not decrease from 2.0062.
#
# Epoch 205/500
# Batch: 1000/1000 - loss: 2.3224 - dice_loss: 0.3975 - disc_loss: 0.3349
#                loss_val: 2.1110 - dice_loss_val: 0.3969 - disc_loss_val: 0.1266
# Validation loss did not decrease from 2.0062.
#
# Epoch 206/500
# Batch: 1000/1000 - loss: 2.3360 - dice_loss: 0.3975 - disc_loss: 0.3486
#                loss_val: 2.1223 - dice_loss_val: 0.3969 - disc_loss_val: 0.1379
# Validation loss did not decrease from 2.0062.
#
# Epoch 207/500
# Batch: 1000/1000 - loss: 2.3783 - dice_loss: 0.3975 - disc_loss: 0.3908
#                loss_val: 2.1333 - dice_loss_val: 0.3969 - disc_loss_val: 0.1488
# Validation loss did not decrease from 2.0062.
#
# Epoch 208/500
# Batch: 1000/1000 - loss: 2.4372 - dice_loss: 0.3975 - disc_loss: 0.4498
#                loss_val: 2.2047 - dice_loss_val: 0.3969 - disc_loss_val: 0.2202
# Validation loss did not decrease from 2.0062.
#
# Epoch 209/500
# Batch: 1000/1000 - loss: 2.4987 - dice_loss: 0.3975 - disc_loss: 0.5112
#                loss_val: 2.2657 - dice_loss_val: 0.3969 - disc_loss_val: 0.2813
# Validation loss did not decrease from 2.0062.
#
# Epoch 210/500
# Batch: 1000/1000 - loss: 2.5749 - dice_loss: 0.3975 - disc_loss: 0.5874
#                loss_val: 2.2526 - dice_loss_val: 0.3969 - disc_loss_val: 0.2681
# Validation loss did not decrease from 2.0062.
#
# Epoch 211/500
# Batch: 1000/1000 - loss: 563.2965 - dice_loss: 0.3975 - disc_loss: 561.30949
#                loss_val: 2.2558 - dice_loss_val: 0.3969 - disc_loss_val: 0.2713
# Validation loss did not decrease from 2.0062.
#
# Epoch 212/500
# Batch: 1000/1000 - loss: 2.7117 - dice_loss: 0.3975 - disc_loss: 0.7243
#                loss_val: 2.1464 - dice_loss_val: 0.3969 - disc_loss_val: 0.1620
# Validation loss did not decrease from 2.0062.
#
# Epoch 213/500
# Batch: 1000/1000 - loss: 3.0248 - dice_loss: 0.3975 - disc_loss: 1.0373
#                loss_val: 4.6880 - dice_loss_val: 0.3969 - disc_loss_val: 2.7035
# Validation loss did not decrease from 2.0062.
#
# Epoch 214/500
# Batch: 1000/1000 - loss: 3.9658 - dice_loss: 0.3975 - disc_loss: 1.9784
#                loss_val: 3.3860 - dice_loss_val: 0.3969 - disc_loss_val: 1.4016
# Validation loss did not decrease from 2.0062.
#
# Epoch 215/500
# Batch: 1000/1000 - loss: 4.1000 - dice_loss: 0.3975 - disc_loss: 2.1125
#                loss_val: 2.6691 - dice_loss_val: 0.3969 - disc_loss_val: 0.6846
# Validation loss did not decrease from 2.0062.
#
# Epoch 216/500
# Batch: 1000/1000 - loss: 329.3661 - dice_loss: 0.3975 - disc_loss: 327.3784
#                loss_val: 2.1208 - dice_loss_val: 0.3969 - disc_loss_val: 0.1364
# ...
#
# Epoch 427/500
# Batch: 1000/1000 - loss: 2.7044 - dice_loss: 0.3975 - disc_loss: 0.7170
#                loss_val: 2.0915 - dice_loss_val: 0.3969 - disc_loss_val: 0.1071
# Validation loss did not decrease from 1.9980.
#
# Epoch 428/500
# Batch: 1000/1000 - loss: 180.8362 - dice_loss: 0.3975 - disc_loss: 178.8489
#                loss_val: 2.7764 - dice_loss_val: 0.3969 - disc_loss_val: 0.7920
# Validation loss did not decrease from 1.9980.
#
# Epoch 429/500
# Batch: 1000/1000 - loss: 2.4247 - dice_loss: 0.3975 - disc_loss: 0.4372
#                loss_val: 2.4704 - dice_loss_val: 0.3969 - disc_loss_val: 0.4860
# Validation loss did not decrease from 1.9980.
#
# Epoch 430/500
# Batch: 1000/1000 - loss: 2.3230 - dice_loss: 0.3975 - disc_loss: 0.3356
#                loss_val: 2.4288 - dice_loss_val: 0.3969 - disc_loss_val: 0.4444
# Validation loss did not decrease from 1.9980.
#
# Epoch 431/500
# Batch: 1000/1000 - loss: 2.3168 - dice_loss: 0.3975 - disc_loss: 0.3293
#                loss_val: 2.4026 - dice_loss_val: 0.3969 - disc_loss_val: 0.4181
# Validation loss did not decrease from 1.9980.
#
# Epoch 432/500
# Batch: 1000/1000 - loss: 2.3178 - dice_loss: 0.3975 - disc_loss: 0.3304
#                loss_val: 2.4140 - dice_loss_val: 0.3969 - disc_loss_val: 0.4295
# Validation loss did not decrease from 1.9980.
#
# Epoch 433/500
# Batch: 1000/1000 - loss: 2.3178 - dice_loss: 0.3975 - disc_loss: 0.3303
#                loss_val: 2.4464 - dice_loss_val: 0.3969 - disc_loss_val: 0.4620
# Validation loss did not decrease from 1.9980.
#
# Epoch 434/500
# Batch: 1000/1000 - loss: 2.3414 - dice_loss: 0.3975 - disc_loss: 0.3540
#                loss_val: 2.4074 - dice_loss_val: 0.3969 - disc_loss_val: 0.4229
# Validation loss did not decrease from 1.9980.
#
# Epoch 435/500
# Batch: 1000/1000 - loss: 2.4932 - dice_loss: 0.3975 - disc_loss: 0.5058
#                loss_val: 2.0341 - dice_loss_val: 0.3969 - disc_loss_val: 0.0497
# Validation loss did not decrease from 1.9980.
#
# Epoch 436/500
# Batch: 1000/1000 - loss: 2.7091 - dice_loss: 0.3975 - disc_loss: 0.7217
#                loss_val: 2.1232 - dice_loss_val: 0.3969 - disc_loss_val: 0.1387
# Validation loss did not decrease from 1.9980.
#
# Epoch 437/500
# Batch: 1000/1000 - loss: 2.8402 - dice_loss: 0.3975 - disc_loss: 0.8528
#                loss_val: 2.0417 - dice_loss_val: 0.3969 - disc_loss_val: 0.0573
# Validation loss did not decrease from 1.9980.
#
# Epoch 438/500
# Batch: 1000/1000 - loss: 2.9167 - dice_loss: 0.3975 - disc_loss: 0.9293
#                loss_val: 2.2049 - dice_loss_val: 0.3969 - disc_loss_val: 0.2204
# Validation loss did not decrease from 1.9980.
#
# Epoch 439/500
# Batch: 1000/1000 - loss: 1082.3934 - dice_loss: 0.3975 - disc_loss: 1080.4080
#                loss_val: 4.3946 - dice_loss_val: 0.3969 - disc_loss_val: 2.4101
# Validation loss did not decrease from 1.9980.
#
# Epoch 440/500
# Batch: 1000/1000 - loss: 3.1770 - dice_loss: 0.3975 - disc_loss: 1.1895
#                loss_val: 2.4460 - dice_loss_val: 0.3969 - disc_loss_val: 0.4616
# Validation loss did not decrease from 1.9980.
#
# Epoch 441/500
# Batch: 1000/1000 - loss: 3.1477 - dice_loss: 0.3975 - disc_loss: 1.1602
#                loss_val: 2.1426 - dice_loss_val: 0.3969 - disc_loss_val: 0.1581
# Validation loss did not decrease from 1.9980.
#
# Epoch 442/500
# Batch: 1000/1000 - loss: 3.0462 - dice_loss: 0.3975 - disc_loss: 1.0587
#                loss_val: 2.2333 - dice_loss_val: 0.3969 - disc_loss_val: 0.2489
# Validation loss did not decrease from 1.9980.
#
# Epoch 443/500
# Batch: 1000/1000 - loss: 2.9872 - dice_loss: 0.3975 - disc_loss: 0.9998
#                loss_val: 2.1080 - dice_loss_val: 0.3969 - disc_loss_val: 0.1235
# Validation loss did not decrease from 1.9980.
#
# Epoch 444/500
# Batch: 1000/1000 - loss: 2.9837 - dice_loss: 0.3975 - disc_loss: 0.9963
#                loss_val: 2.2219 - dice_loss_val: 0.3969 - disc_loss_val: 0.2374
# Validation loss did not decrease from 1.9980.
#
# Epoch 445/500
# Batch: 1000/1000 - loss: 311.8286 - dice_loss: 0.3975 - disc_loss: 309.8410
#                loss_val: 2.5519 - dice_loss_val: 0.3969 - disc_loss_val: 0.5675
# Validation loss did not decrease from 1.9980.
#
# Epoch 446/500
# Batch: 1000/1000 - loss: 2.5365 - dice_loss: 0.3975 - disc_loss: 0.5491
#                loss_val: 2.4682 - dice_loss_val: 0.3969 - disc_loss_val: 0.4838
# Validation loss did not decrease from 1.9980.
#
# Epoch 447/500
# Batch: 1000/1000 - loss: 2.5264 - dice_loss: 0.3975 - disc_loss: 0.5390
#                loss_val: 2.1921 - dice_loss_val: 0.3969 - disc_loss_val: 0.2077
# Validation loss did not decrease from 1.9980.
#
# Epoch 448/500
# Batch: 1000/1000 - loss: 2.6101 - dice_loss: 0.3975 - disc_loss: 0.6226
#                loss_val: 2.0620 - dice_loss_val: 0.3969 - disc_loss_val: 0.0775
# Validation loss did not decrease from 1.9980.
#
# Epoch 449/500
# Batch: 1000/1000 - loss: 2.6800 - dice_loss: 0.3975 - disc_loss: 0.6926
#                loss_val: 2.0086 - dice_loss_val: 0.3969 - disc_loss_val: 0.0241
# Validation loss did not decrease from 1.9980.
#
# Epoch 450/500
# Batch: 1000/1000 - loss: 2.7278 - dice_loss: 0.3975 - disc_loss: 0.7404
#                loss_val: 2.0217 - dice_loss_val: 0.3969 - disc_loss_val: 0.0372
# Validation loss did not decrease from 1.9980.
#
# Epoch 451/500
# Batch: 1000/1000 - loss: 250.1666 - dice_loss: 0.3975 - disc_loss: 248.1792
#                loss_val: 2.7091 - dice_loss_val: 0.3969 - disc_loss_val: 0.7246
# Validation loss did not decrease from 1.9980.
#
# Epoch 452/500
# Batch: 1000/1000 - loss: 2.5060 - dice_loss: 0.3975 - disc_loss: 0.5185
#                loss_val: 2.3973 - dice_loss_val: 0.3969 - disc_loss_val: 0.4128
# Validation loss did not decrease from 1.9980.
#
# Epoch 453/500
# Batch: 1000/1000 - loss: 2.5259 - dice_loss: 0.3975 - disc_loss: 0.5384
#                loss_val: 2.2583 - dice_loss_val: 0.3969 - disc_loss_val: 0.2739
# Validation loss did not decrease from 1.9980.
#
# Epoch 454/500
# Batch: 1000/1000 - loss: 2.5749 - dice_loss: 0.3975 - disc_loss: 0.5874
#                loss_val: 2.1920 - dice_loss_val: 0.3969 - disc_loss_val: 0.2075
# Validation loss did not decrease from 1.9980.
#
# Epoch 455/500
# Batch: 1000/1000 - loss: 2.6079 - dice_loss: 0.3975 - disc_loss: 0.6204
#                loss_val: 2.2471 - dice_loss_val: 0.3969 - disc_loss_val: 0.2627
# Validation loss did not decrease from 1.9980.
#
# Epoch 456/500
# Batch: 1000/1000 - loss: 2.6512 - dice_loss: 0.3975 - disc_loss: 0.6637
#                loss_val: 2.3037 - dice_loss_val: 0.3969 - disc_loss_val: 0.3192
# Validation loss did not decrease from 1.9980.
#
# Epoch 457/500
# Batch: 1000/1000 - loss: 2.7001 - dice_loss: 0.3975 - disc_loss: 0.7127
#                loss_val: 2.3344 - dice_loss_val: 0.3969 - disc_loss_val: 0.3500
# Validation loss did not decrease from 1.9980.
#
# Epoch 458/500
# Batch: 1000/1000 - loss: 2.7641 - dice_loss: 0.3975 - disc_loss: 0.7767
#                loss_val: 2.1226 - dice_loss_val: 0.3969 - disc_loss_val: 0.1382
# Validation loss did not decrease from 1.9980.
#
# Epoch 459/500
# Batch: 1000/1000 - loss: 2.8426 - dice_loss: 0.3975 - disc_loss: 0.8552
#                loss_val: 2.1834 - dice_loss_val: 0.3969 - disc_loss_val: 0.1990
# Validation loss did not decrease from 1.9980.
#
# Epoch 460/500
# Batch: 1000/1000 - loss: 248.8235 - dice_loss: 0.3975 - disc_loss: 246.8361
#                loss_val: 2.3339 - dice_loss_val: 0.3969 - disc_loss_val: 0.3495
# Validation loss did not decrease from 1.9980.
#
# Epoch 461/500
# Batch: 1000/1000 - loss: 2.7060 - dice_loss: 0.3975 - disc_loss: 0.7186
#                loss_val: 2.1401 - dice_loss_val: 0.3969 - disc_loss_val: 0.1557
# Validation loss did not decrease from 1.9980.
#
# Epoch 462/500
# Batch: 1000/1000 - loss: 2.6396 - dice_loss: 0.3975 - disc_loss: 0.6522
#                loss_val: 2.0552 - dice_loss_val: 0.3969 - disc_loss_val: 0.0707
# Validation loss did not decrease from 1.9980.
#
# Epoch 463/500
# Batch: 1000/1000 - loss: 2.6319 - dice_loss: 0.3975 - disc_loss: 0.6445
#                loss_val: 2.0557 - dice_loss_val: 0.3969 - disc_loss_val: 0.0713
# Validation loss did not decrease from 1.9980.
#
# Epoch 464/500
# Batch: 1000/1000 - loss: 2.6412 - dice_loss: 0.3975 - disc_loss: 0.6537
#                loss_val: 2.0870 - dice_loss_val: 0.3969 - disc_loss_val: 0.1026
# Validation loss did not decrease from 1.9980.
#
# Epoch 465/500
# Batch: 1000/1000 - loss: 2.6722 - dice_loss: 0.3975 - disc_loss: 0.6848
#                loss_val: 2.0861 - dice_loss_val: 0.3969 - disc_loss_val: 0.1016
# Validation loss did not decrease from 1.9980.
#
# Epoch 466/500
# Batch: 1000/1000 - loss: 2.6865 - dice_loss: 0.3975 - disc_loss: 0.6991
#                loss_val: 2.1382 - dice_loss_val: 0.3969 - disc_loss_val: 0.1538
# Validation loss did not decrease from 1.9980.
#
# Epoch 467/500
# Batch: 1000/1000 - loss: 2.6945 - dice_loss: 0.3975 - disc_loss: 0.7071
#                loss_val: 2.2293 - dice_loss_val: 0.3969 - disc_loss_val: 0.2448
# Validation loss did not decrease from 1.9980.
#
# Epoch 468/500
# Batch: 1000/1000 - loss: 2.7449 - dice_loss: 0.3975 - disc_loss: 0.7574
#                loss_val: 2.1461 - dice_loss_val: 0.3969 - disc_loss_val: 0.1617
# Validation loss did not decrease from 1.9980.
#
# Epoch 469/500
# Batch: 1000/1000 - loss: 2.8121 - dice_loss: 0.3975 - disc_loss: 0.8246
#                loss_val: 2.0676 - dice_loss_val: 0.3969 - disc_loss_val: 0.0831
# Validation loss did not decrease from 1.9980.
#
# Epoch 470/500
# Batch: 1000/1000 - loss: 2.8524 - dice_loss: 0.3975 - disc_loss: 0.8650
#                loss_val: 2.0944 - dice_loss_val: 0.3969 - disc_loss_val: 0.1099
# Validation loss did not decrease from 1.9980.
#
# Epoch 471/500
# Batch: 1000/1000 - loss: 2.8722 - dice_loss: 0.3975 - disc_loss: 0.8847
#                loss_val: 2.1309 - dice_loss_val: 0.3969 - disc_loss_val: 0.1465
# Validation loss did not decrease from 1.9980.
#
# Epoch 472/500
# Batch: 1000/1000 - loss: 347.3304 - dice_loss: 0.3975 - disc_loss: 345.3428
#                loss_val: 5.6481 - dice_loss_val: 0.3969 - disc_loss_val: 3.6637
# Validation loss did not decrease from 1.9980.
#
# Epoch 473/500
# Batch: 1000/1000 - loss: 3.3588 - dice_loss: 0.3975 - disc_loss: 1.3714
#                loss_val: 2.8195 - dice_loss_val: 0.3969 - disc_loss_val: 0.8350
# Validation loss did not decrease from 1.9980.
#
# Epoch 474/500
# Batch: 1000/1000 - loss: 2.8453 - dice_loss: 0.3975 - disc_loss: 0.8579
#                loss_val: 2.6358 - dice_loss_val: 0.3969 - disc_loss_val: 0.6513
# Validation loss did not decrease from 1.9980.
#
# Epoch 475/500
# Batch: 1000/1000 - loss: 2.8781 - dice_loss: 0.3975 - disc_loss: 0.8907
#                loss_val: 2.7497 - dice_loss_val: 0.3969 - disc_loss_val: 0.7652
# Validation loss did not decrease from 1.9980.
#
# Epoch 476/500
# Batch: 1000/1000 - loss: 2.9114 - dice_loss: 0.3975 - disc_loss: 0.9239
#                loss_val: 2.5170 - dice_loss_val: 0.3969 - disc_loss_val: 0.5325
# Validation loss did not decrease from 1.9980.
#
# Epoch 477/500
# Batch: 1000/1000 - loss: 432.6012 - dice_loss: 0.3975 - disc_loss: 430.6134
#                loss_val: 18.1387 - dice_loss_val: 0.3969 - disc_loss_val: 16.1543
# Validation loss did not decrease from 1.9980.
#
# Epoch 478/500
# Batch: 1000/1000 - loss: 6.3246 - dice_loss: 0.3975 - disc_loss: 4.3372
#                loss_val: 4.3453 - dice_loss_val: 0.3969 - disc_loss_val: 2.3609
# Validation loss did not decrease from 1.9980.
#
# Epoch 479/500
# Batch: 1000/1000 - loss: 3.9624 - dice_loss: 0.3975 - disc_loss: 1.9749
#                loss_val: 2.6898 - dice_loss_val: 0.3969 - disc_loss_val: 0.7054
# Validation loss did not decrease from 1.9980.
#
# Epoch 480/500
# Batch: 1000/1000 - loss: 3.4231 - dice_loss: 0.3975 - disc_loss: 1.4357
#                loss_val: 2.4960 - dice_loss_val: 0.3969 - disc_loss_val: 0.5116
# Validation loss did not decrease from 1.9980.
#
# Epoch 481/500
# Batch: 1000/1000 - loss: 3.6413 - dice_loss: 0.3975 - disc_loss: 1.6538
#                loss_val: 2.9550 - dice_loss_val: 0.3969 - disc_loss_val: 0.9705
# Validation loss did not decrease from 1.9980.
#
# Epoch 482/500
# Batch: 1000/1000 - loss: 77.4380 - dice_loss: 0.3975 - disc_loss: 75.4506
#                loss_val: 2.4797 - dice_loss_val: 0.3969 - disc_loss_val: 0.4953
# Validation loss did not decrease from 1.9980.
#
# Epoch 483/500
# Batch: 1000/1000 - loss: 2.6403 - dice_loss: 0.3975 - disc_loss: 0.6528
#                loss_val: 2.3357 - dice_loss_val: 0.3969 - disc_loss_val: 0.3513
# Validation loss did not decrease from 1.9980.
#
# Epoch 484/500
# Batch: 1000/1000 - loss: 2.6417 - dice_loss: 0.3975 - disc_loss: 0.6542
#                loss_val: 2.3346 - dice_loss_val: 0.3969 - disc_loss_val: 0.3502
# Validation loss did not decrease from 1.9980.
#
# Epoch 485/500
# Batch: 1000/1000 - loss: 2.6821 - dice_loss: 0.3975 - disc_loss: 0.6946
#                loss_val: 2.3755 - dice_loss_val: 0.3969 - disc_loss_val: 0.3911
# Validation loss did not decrease from 1.9980.
#
# Epoch 486/500
# Batch: 1000/1000 - loss: 2.6957 - dice_loss: 0.3975 - disc_loss: 0.7082
#                loss_val: 2.4226 - dice_loss_val: 0.3969 - disc_loss_val: 0.4381
# Validation loss did not decrease from 1.9980.
#
# Epoch 487/500
# Batch: 1000/1000 - loss: 2.6787 - dice_loss: 0.3975 - disc_loss: 0.6913
#                loss_val: 2.3637 - dice_loss_val: 0.3969 - disc_loss_val: 0.3793
# Validation loss did not decrease from 1.9980.
#
# Epoch 488/500
# Batch: 1000/1000 - loss: 2.6842 - dice_loss: 0.3975 - disc_loss: 0.6968
#                loss_val: 2.3631 - dice_loss_val: 0.3969 - disc_loss_val: 0.3787
# Validation loss did not decrease from 1.9980.
#
# Epoch 489/500
# Batch: 1000/1000 - loss: 2.6895 - dice_loss: 0.3975 - disc_loss: 0.7021
#                loss_val: 2.2349 - dice_loss_val: 0.3969 - disc_loss_val: 0.2504
# Validation loss did not decrease from 1.9980.
#
# Epoch 490/500
# Batch: 1000/1000 - loss: 2.7251 - dice_loss: 0.3975 - disc_loss: 0.7377
#                loss_val: 2.0620 - dice_loss_val: 0.3969 - disc_loss_val: 0.0776
# Validation loss did not decrease from 1.9980.
#
# Epoch 491/500
# Batch: 1000/1000 - loss: 2.7510 - dice_loss: 0.3975 - disc_loss: 0.7636
#                loss_val: 2.1181 - dice_loss_val: 0.3969 - disc_loss_val: 0.1336
# Validation loss did not decrease from 1.9980.
#
# Epoch 492/500
# Batch: 1000/1000 - loss: 2.7805 - dice_loss: 0.3975 - disc_loss: 0.7931
#                loss_val: 2.5741 - dice_loss_val: 0.3969 - disc_loss_val: 0.5896
# Validation loss did not decrease from 1.9980.
#
# Epoch 493/500
# Batch: 1000/1000 - loss: 303.2609 - dice_loss: 0.3975 - disc_loss: 301.27395
#                loss_val: 2.5711 - dice_loss_val: 0.3969 - disc_loss_val: 0.5866
# Validation loss did not decrease from 1.9980.
#
# Epoch 494/500
# Batch: 1000/1000 - loss: 2.7461 - dice_loss: 0.3975 - disc_loss: 0.7587
#                loss_val: 2.2578 - dice_loss_val: 0.3969 - disc_loss_val: 0.2733
# Validation loss did not decrease from 1.9980.
#
# Epoch 495/500
# Batch: 1000/1000 - loss: 2.8143 - dice_loss: 0.3975 - disc_loss: 0.8269
#                loss_val: 2.2302 - dice_loss_val: 0.3969 - disc_loss_val: 0.2458
# Validation loss did not decrease from 1.9980.
#
# Epoch 496/500
# Batch: 1000/1000 - loss: 2.8145 - dice_loss: 0.3975 - disc_loss: 0.8270
#                loss_val: 2.0962 - dice_loss_val: 0.3969 - disc_loss_val: 0.1118
# Validation loss did not decrease from 1.9980.
#
# Epoch 497/500
# Batch: 1000/1000 - loss: 2.8132 - dice_loss: 0.3975 - disc_loss: 0.8258
#                loss_val: 2.0961 - dice_loss_val: 0.3969 - disc_loss_val: 0.1116
# Validation loss did not decrease from 1.9980.
#
# Epoch 498/500
# Batch: 1000/1000 - loss: 2.8638 - dice_loss: 0.3975 - disc_loss: 0.8764
#                loss_val: 2.1396 - dice_loss_val: 0.3969 - disc_loss_val: 0.1552
# Validation loss did not decrease from 1.9980.
#
# Epoch 499/500
# Batch: 1000/1000 - loss: 43.7315 - dice_loss: 0.3975 - disc_loss: 41.7441
#                loss_val: 2.0239 - dice_loss_val: 0.3969 - disc_loss_val: 0.0395
# Validation loss did not decrease from 1.9980.
#
# Epoch 500/500
# Batch: 1000/1000 - loss: 2.5476 - dice_loss: 0.3975 - disc_loss: 0.5602
#                loss_val: 2.0057 - dice_loss_val: 0.3969 - disc_loss_val: 0.0213
# Validation loss did not decrease from 1.9980.
#
# 794276.0539782047
